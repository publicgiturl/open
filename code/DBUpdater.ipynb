# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib, pymysql, calendar, time, json
from urllib.request import urlopen
from datetime import datetime
from threading import Timer

class DBUpdater:  
    def __init__(self):
        """생성자: MariaDB 연결 및 종목코드 딕셔너리 생성"""
        self.conn = pymysql.connect(host='localhost', user='root',
            password='1234', db='INVESTAR', charset='utf8')
        
        with self.conn.cursor() as curs:
            sql = """
            CREATE TABLE IF NOT EXISTS company_info (
                code VARCHAR(20),
                company VARCHAR(40),
                last_update DATE,
                PRIMARY KEY (code))
            """
            curs.execute(sql)
            sql = """
            CREATE TABLE IF NOT EXISTS daily_price (
                code VARCHAR(20),
                date DATE,
                open BIGINT(20),
                high BIGINT(20),
                low BIGINT(20),
                close BIGINT(20),
                diff BIGINT(20),
                volume BIGINT(20),
                PRIMARY KEY (code, date))
            """
            curs.execute(sql)
        self.conn.commit()
        self.codes = dict()
               
    def __del__(self):
        """소멸자: MariaDB 연결 해제"""
        self.conn.close() 
     
    def read_krx_code(self):
        """KRX로부터 상장기업 목록 파일을 읽어와서 데이터프레임으로 반환"""
        url = 'http://kind.krx.co.kr/corpgeneral/corpList.do?method='\
            'download&searchType=13'
        krx = pd.read_html(url, header=0)[0]
        krx = krx[['종목코드', '회사명']]
        krx = krx.rename(columns={'종목코드': 'code', '회사명': 'company'})
        krx.code = krx.code.map('{:06d}'.format)
        return krx
    
    def update_comp_info(self):
        """종목코드를 company_info 테이블에 업데이트 한 후 딕셔너리에 저장"""
        sql = "SELECT * FROM company_info"
        df = pd.read_sql(sql, self.conn)
        for idx in range(len(df)):
            self.codes[df['code'].values[idx]] = df['company'].values[idx]
                    
        with self.conn.cursor() as curs:
            sql = "SELECT max(last_update) FROM company_info"
            curs.execute(sql)
            rs = curs.fetchone()
            today = datetime.today().strftime('%Y-%m-%d')
            if rs[0] == None or rs[0].strftime('%Y-%m-%d') < today:
                krx = self.read_krx_code()
                for idx in range(len(krx)):
                    code = krx.code.values[idx]
                    company = krx.company.values[idx]                
                    sql = f"REPLACE INTO company_info (code, company, last"\
                        f"_update) VALUES ('{code}', '{company}', '{today}')"
                    curs.execute(sql)
                    self.codes[code] = company
                    tmnow = datetime.now().strftime('%Y-%m-%d %H:%M')
                    print(f"[{tmnow}] #{idx+1:04d} REPLACE INTO company_info "\
                        f"VALUES ({code}, {company}, {today})")
                self.conn.commit()
                print('')              

    def read_naver(self, code, company, pages_to_fetch):
        """네이버에서 주식 시세를 읽어서 데이터프레임으로 반환"""
        try:
            url = f"http://finance.naver.com/item/sise_day.nhn?code={code}"
            with urlopen(url) as doc:
                if doc is None:
                    return None
                html = BeautifulSoup(doc, "lxml")
                pgrr = html.find("td", class_="pgRR")
                if pgrr is None:
                    return None
                s = str(pgrr.a["href"]).split('=')
                lastpage = s[-1] 
            df = pd.DataFrame()
            pages = min(int(lastpage), pages_to_fetch)
            for page in range(1, pages + 1):
                pg_url = '{}&page={}'.format(url, page)
                df = df.append(pd.read_html(pg_url, header=0)[0])
                tmnow = datetime.now().strftime('%Y-%m-%d %H:%M')
                print('[{}] {} ({}) : {:04d}/{:04d} pages are downloading...'.
                    format(tmnow, company, code, page, pages), end="\r")
            df = df.rename(columns={'날짜':'date','종가':'close','전일비':'diff'
                ,'시가':'open','고가':'high','저가':'low','거래량':'volume'})
            df['date'] = df['date'].replace('.', '-')
            df = df.dropna()
            df[['close', 'diff', 'open', 'high', 'low', 'volume']] = df[['close',
                'diff', 'open', 'high', 'low', 'volume']].astype(int)
            df = df[['date', 'open', 'high', 'low', 'close', 'diff', 'volume']]
        except Exception as e:
            print('Exception occured :', str(e))
            return None
        return df

    def replace_into_db(self, df, num, code, company):
        """네이버에서 읽어온 주식 시세를 DB에 REPLACE"""
        with self.conn.cursor() as curs:
            for r in df.itertuples():
                sql = f"REPLACE INTO daily_price VALUES ('{code}', "\
                    f"'{r.date}', {r.open}, {r.high}, {r.low}, {r.close}, "\
                    f"{r.diff}, {r.volume})"
                curs.execute(sql)
            self.conn.commit()
            print('[{}] #{:04d} {} ({}) : {} rows > REPLACE INTO daily_'\
                'price [OK]'.format(datetime.now().strftime('%Y-%m-%d'\
                ' %H:%M'), num+1, company, code, len(df)))

    def update_daily_price(self, pages_to_fetch):
        """KRX 상장법인의 주식 시세를 네이버로부터 읽어서 DB에 업데이트"""  
        for idx, code in enumerate(self.codes):
            df = self.read_naver(code, self.codes[code], pages_to_fetch)
            if df is None:
                continue
            self.replace_into_db(df, idx, code, self.codes[code])            

    def execute_daily(self):
        """실행 즉시 및 매일 오후 다섯시에 daily_price 테이블 업데이트"""
        self.update_comp_info()
        
        try:
            with open('config.json', 'r') as in_file:
                config = json.load(in_file)
                pages_to_fetch = config['pages_to_fetch']
        except FileNotFoundError:
            with open('config.json', 'w') as out_file:
                # 총 610페이지
                pages_to_fetch = 50 
                config = {'pages_to_fetch': 1}
                json.dump(config, out_file)
        self.update_daily_price(pages_to_fetch)

        tmnow = datetime.now()
        lastday = calendar.monthrange(tmnow.year, tmnow.month)[1]
        if tmnow.month == 12 and tmnow.day == lastday:
            tmnext = tmnow.replace(year=tmnow.year+1, month=1, day=1,
                hour=17, minute=0, second=0)
        elif tmnow.day == lastday:
            tmnext = tmnow.replace(month=tmnow.month+1, day=1, hour=17,
                minute=0, second=0)
        else:
            tmnext = tmnow.replace(day=tmnow.day+1, hour=17, minute=0,
                second=0)   
        tmdiff = tmnext - tmnow
        secs = tmdiff.seconds
        t = Timer(secs, self.execute_daily)
        print("Waiting for next update ({}) ... ".format(tmnext.strftime
            ('%Y-%m-%d %H:%M')))
        t.start()

if __name__ == '__main__':
    dbu = DBUpdater()
    dbu.execute_daily()
# Out:
# [2020-10-29 12:00] #0001 REPLACE INTO company_info VALUES (155660, DSR, 2020-10-29)
# [2020-10-29 12:00] #0002 REPLACE INTO company_info VALUES (001250, GS글로벌, 2020-10-29)
# [2020-10-29 12:00] #0003 REPLACE INTO company_info VALUES (294870, HDC현대산업개발, 2020-10-29)
# [2020-10-29 12:00] #0004 REPLACE INTO company_info VALUES (092220, KEC, 2020-10-29)
# [2020-10-29 12:00] #0005 REPLACE INTO company_info VALUES (001390, KG케미칼, 2020-10-29)
# [2020-10-29 12:00] #0006 REPLACE INTO company_info VALUES (011070, LG이노텍, 2020-10-29)
# [2020-10-29 12:00] #0007 REPLACE INTO company_info VALUES (066570, LG전자, 2020-10-29)
# [2020-10-29 12:00] #0008 REPLACE INTO company_info VALUES (037560, LG헬로비전, 2020-10-29)
# [2020-10-29 12:00] #0009 REPLACE INTO company_info VALUES (010060, OCI, 2020-10-29)
# [2020-10-29 12:00] #0010 REPLACE INTO company_info VALUES (100840, S&TC, 2020-10-29)
# [2020-10-29 12:00] #0011 REPLACE INTO company_info VALUES (064960, S&T모티브, 2020-10-29)
# [2020-10-29 12:00] #0012 REPLACE INTO company_info VALUES (096770, SK이노베이션, 2020-10-29)
# [2020-10-29 12:00] #0013 REPLACE INTO company_info VALUES (011810, STX, 2020-10-29)
# [2020-10-29 12:00] #0014 REPLACE INTO company_info VALUES (024070, WISCOM, 2020-10-29)
# [2020-10-29 12:00] #0015 REPLACE INTO company_info VALUES (037270, YG PLUS, 2020-10-29)
# [2020-10-29 12:00] #0016 REPLACE INTO company_info VALUES (011420, 갤럭시아에스엠, 2020-10-29)
# [2020-10-29 12:00] #0017 REPLACE INTO company_info VALUES (010130, 고려아연, 2020-10-29)
# [2020-10-29 12:00] #0018 REPLACE INTO company_info VALUES (014530, 극동유화, 2020-10-29)
# [2020-10-29 12:00] #0019 REPLACE INTO company_info VALUES (013700, 까뮤이앤씨, 2020-10-29)
# [2020-10-29 12:00] #0020 REPLACE INTO company_info VALUES (008060, 대덕, 2020-10-29)
# [2020-10-29 12:00] #0021 REPLACE INTO company_info VALUES (353200, 대덕전자, 2020-10-29)
# [2020-10-29 12:00] #0022 REPLACE INTO company_info VALUES (014160, 대영포장, 2020-10-29)
# [2020-10-29 12:00] #0023 REPLACE INTO company_info VALUES (006650, 대한유화, 2020-10-29)
# [2020-10-29 12:00] #0024 REPLACE INTO company_info VALUES (000640, 동아쏘시오홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0025 REPLACE INTO company_info VALUES (000150, 두산, 2020-10-29)
# [2020-10-29 12:00] #0026 REPLACE INTO company_info VALUES (241560, 두산밥캣, 2020-10-29)
# [2020-10-29 12:00] #0027 REPLACE INTO company_info VALUES (115390, 락앤락, 2020-10-29)
# [2020-10-29 12:00] #0028 REPLACE INTO company_info VALUES (027740, 마니커, 2020-10-29)
# [2020-10-29 12:00] #0029 REPLACE INTO company_info VALUES (204320, 만도, 2020-10-29)
# [2020-10-29 12:00] #0030 REPLACE INTO company_info VALUES (008560, 메리츠증권, 2020-10-29)
# [2020-10-29 12:00] #0031 REPLACE INTO company_info VALUES (204210, 모두투어리츠, 2020-10-29)
# [2020-10-29 12:00] #0032 REPLACE INTO company_info VALUES (001270, 부국증권, 2020-10-29)
# [2020-10-29 12:00] #0033 REPLACE INTO company_info VALUES (006400, 삼성SDI, 2020-10-29)
# [2020-10-29 12:00] #0034 REPLACE INTO company_info VALUES (028050, 삼성엔지니어링, 2020-10-29)
# [2020-10-29 12:00] #0035 REPLACE INTO company_info VALUES (010140, 삼성중공업, 2020-10-29)
# [2020-10-29 12:00] #0036 REPLACE INTO company_info VALUES (068290, 삼성출판사, 2020-10-29)
# [2020-10-29 12:00] #0037 REPLACE INTO company_info VALUES (000810, 삼성화재해상보험, 2020-10-29)
# [2020-10-29 12:00] #0038 REPLACE INTO company_info VALUES (003230, 삼양식품, 2020-10-29)
# [2020-10-29 12:00] #0039 REPLACE INTO company_info VALUES (000070, 삼양홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0040 REPLACE INTO company_info VALUES (005680, 삼영전자공업, 2020-10-29)
# [2020-10-29 12:00] #0041 REPLACE INTO company_info VALUES (003720, 삼영화학공업, 2020-10-29)
# [2020-10-29 12:00] #0042 REPLACE INTO company_info VALUES (001290, 상상인증권, 2020-10-29)
# [2020-10-29 12:00] #0043 REPLACE INTO company_info VALUES (007610, 선도전기, 2020-10-29)
# [2020-10-29 12:00] #0044 REPLACE INTO company_info VALUES (136490, 선진, 2020-10-29)
# [2020-10-29 12:00] #0045 REPLACE INTO company_info VALUES (004490, 세방전지, 2020-10-29)
# [2020-10-29 12:00] #0046 REPLACE INTO company_info VALUES (091090, 세원셀론텍, 2020-10-29)
# [2020-10-29 12:00] #0047 REPLACE INTO company_info VALUES (293940, 신한알파리츠, 2020-10-29)
# [2020-10-29 12:00] #0048 REPLACE INTO company_info VALUES (055550, 신한지주, 2020-10-29)
# [2020-10-29 12:00] #0049 REPLACE INTO company_info VALUES (003620, 쌍용자동차, 2020-10-29)
# [2020-10-29 12:00] #0050 REPLACE INTO company_info VALUES (011090, 에넥스, 2020-10-29)
# [2020-10-29 12:00] #0051 REPLACE INTO company_info VALUES (012280, 영화금속, 2020-10-29)
# [2020-10-29 12:00] #0052 REPLACE INTO company_info VALUES (008600, 윌비스, 2020-10-29)
# [2020-10-29 12:00] #0053 REPLACE INTO company_info VALUES (033270, 유나이티드, 2020-10-29)
# [2020-10-29 12:00] #0054 REPLACE INTO company_info VALUES (023800, 인지컨트롤스, 2020-10-29)
# [2020-10-29 12:00] #0055 REPLACE INTO company_info VALUES (129260, 인터지스, 2020-10-29)
# [2020-10-29 12:00] #0056 REPLACE INTO company_info VALUES (013360, 일성건설, 2020-10-29)
# [2020-10-29 12:00] #0057 REPLACE INTO company_info VALUES (081000, 일진다이아, 2020-10-29)
# [2020-10-29 12:00] #0058 REPLACE INTO company_info VALUES (271980, 제일약품, 2020-10-29)
# [2020-10-29 12:00] #0059 REPLACE INTO company_info VALUES (001560, 제일연마, 2020-10-29)
# [2020-10-29 12:00] #0060 REPLACE INTO company_info VALUES (002620, 제일파마홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0061 REPLACE INTO company_info VALUES (002600, 조흥, 2020-10-29)
# [2020-10-29 12:00] #0062 REPLACE INTO company_info VALUES (071320, 지역난방공사, 2020-10-29)
# [2020-10-29 12:00] #0063 REPLACE INTO company_info VALUES (088790, 진도, 2020-10-29)
# [2020-10-29 12:00] #0064 REPLACE INTO company_info VALUES (120110, 코오롱인더, 2020-10-29)
# [2020-10-29 12:00] #0065 REPLACE INTO company_info VALUES (020120, 키다리스튜디오, 2020-10-29)
# [2020-10-29 12:00] #0066 REPLACE INTO company_info VALUES (015890, 태경산업, 2020-10-29)
# [2020-10-29 12:00] #0067 REPLACE INTO company_info VALUES (004100, 태양금속공업, 2020-10-29)
# [2020-10-29 12:00] #0068 REPLACE INTO company_info VALUES (058430, 포스코강판, 2020-10-29)
# [2020-10-29 12:00] #0069 REPLACE INTO company_info VALUES (033180, 필룩스, 2020-10-29)
# [2020-10-29 12:00] #0070 REPLACE INTO company_info VALUES (005430, 한국공항, 2020-10-29)
# [2020-10-29 12:00] #0071 REPLACE INTO company_info VALUES (023350, 한국종합기술, 2020-10-29)
# [2020-10-29 12:00] #0072 REPLACE INTO company_info VALUES (104700, 한국철강, 2020-10-29)
# [2020-10-29 12:00] #0073 REPLACE INTO company_info VALUES (168490, 한국패러랠, 2020-10-29)
# [2020-10-29 12:00] #0074 REPLACE INTO company_info VALUES (060980, 한라홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0075 REPLACE INTO company_info VALUES (128940, 한미약품, 2020-10-29)
# [2020-10-29 12:00] #0076 REPLACE INTO company_info VALUES (009180, 한솔로지스틱스, 2020-10-29)
# [2020-10-29 12:00] #0077 REPLACE INTO company_info VALUES (002220, 한일철강, 2020-10-29)
# [2020-10-29 12:00] #0078 REPLACE INTO company_info VALUES (006390, 한일현대시멘트, 2020-10-29)
# [2020-10-29 12:00] #0079 REPLACE INTO company_info VALUES (009460, 한창제지, 2020-10-29)
# [2020-10-29 12:00] #0080 REPLACE INTO company_info VALUES (088350, 한화생명, 2020-10-29)
# [2020-10-29 12:00] #0081 REPLACE INTO company_info VALUES (272210, 한화시스템, 2020-10-29)
# [2020-10-29 12:00] #0082 REPLACE INTO company_info VALUES (000720, 현대건설, 2020-10-29)
# [2020-10-29 12:00] #0083 REPLACE INTO company_info VALUES (267270, 현대건설기계, 2020-10-29)
# [2020-10-29 12:00] #0084 REPLACE INTO company_info VALUES (012330, 현대모비스, 2020-10-29)
# [2020-10-29 12:00] #0085 REPLACE INTO company_info VALUES (004560, 현대비앤지스틸, 2020-10-29)
# [2020-10-29 12:00] #0086 REPLACE INTO company_info VALUES (017800, 현대엘리베이터, 2020-10-29)
# [2020-10-29 12:00] #0087 REPLACE INTO company_info VALUES (001500, 현대차증권, 2020-10-29)
# [2020-10-29 12:00] #0088 REPLACE INTO company_info VALUES (057050, 현대홈쇼핑, 2020-10-29)
# [2020-10-29 12:00] #0089 REPLACE INTO company_info VALUES (111110, 호전실업, 2020-10-29)
# [2020-10-29 12:00] #0090 REPLACE INTO company_info VALUES (051500, CJ프레시웨이, 2020-10-29)
# [2020-10-29 12:00] #0091 REPLACE INTO company_info VALUES (245620, EDGC, 2020-10-29)
# [2020-10-29 12:00] #0092 REPLACE INTO company_info VALUES (083450, GST, 2020-10-29)
# [2020-10-29 12:00] #0093 REPLACE INTO company_info VALUES (028150, GS홈쇼핑, 2020-10-29)
# [2020-10-29 12:00] #0094 REPLACE INTO company_info VALUES (351340, IBKS제13호스팩, 2020-10-29)
# [2020-10-29 12:00] #0095 REPLACE INTO company_info VALUES (099520, ITX-AI, 2020-10-29)
# [2020-10-29 12:00] #0096 REPLACE INTO company_info VALUES (067290, JW신약, 2020-10-29)
# [2020-10-29 12:00] #0097 REPLACE INTO company_info VALUES (024120, KB오토시스, 2020-10-29)
# [2020-10-29 12:00] #0098 REPLACE INTO company_info VALUES (060720, KH바텍, 2020-10-29)
# [2020-10-29 12:00] #0099 REPLACE INTO company_info VALUES (114450, KPX생명과학, 2020-10-29)
# [2020-10-29 12:00] #0100 REPLACE INTO company_info VALUES (337450, SK5호스팩, 2020-10-29)
# [2020-10-29 12:00] #0101 REPLACE INTO company_info VALUES (340350, SK6호스팩, 2020-10-29)
# [2020-10-29 12:00] #0102 REPLACE INTO company_info VALUES (032540, TJ미디어, 2020-10-29)
# [2020-10-29 12:00] #0103 REPLACE INTO company_info VALUES (051390, YW, 2020-10-29)
# [2020-10-29 12:00] #0104 REPLACE INTO company_info VALUES (024910, 경창산업, 2020-10-29)
# [2020-10-29 12:00] #0105 REPLACE INTO company_info VALUES (198440, 고려시멘트, 2020-10-29)
# [2020-10-29 12:00] #0106 REPLACE INTO company_info VALUES (215000, 골프존, 2020-10-29)
# [2020-10-29 12:00] #0107 REPLACE INTO company_info VALUES (307280, 교보8호스팩, 2020-10-29)
# [2020-10-29 12:00] #0108 REPLACE INTO company_info VALUES (043650, 국순당, 2020-10-29)
# [2020-10-29 12:00] #0109 REPLACE INTO company_info VALUES (204020, 그리티, 2020-10-29)
# [2020-10-29 12:00] #0110 REPLACE INTO company_info VALUES (286750, 나노브릭, 2020-10-29)
# [2020-10-29 12:00] #0111 REPLACE INTO company_info VALUES (089600, 나스미디어, 2020-10-29)
# [2020-10-29 12:00] #0112 REPLACE INTO company_info VALUES (085910, 네오티스, 2020-10-29)
# [2020-10-29 12:00] #0113 REPLACE INTO company_info VALUES (007390, 네이처셀, 2020-10-29)
# [2020-10-29 12:00] #0114 REPLACE INTO company_info VALUES (031390, 녹십자셀, 2020-10-29)
# [2020-10-29 12:00] #0115 REPLACE INTO company_info VALUES (012340, 뉴인텍, 2020-10-29)
# [2020-10-29 12:00] #0116 REPLACE INTO company_info VALUES (085670, 뉴프렉스, 2020-10-29)
# [2020-10-29 12:00] #0117 REPLACE INTO company_info VALUES (078140, 대봉엘에스, 2020-10-29)
# [2020-10-29 12:00] #0118 REPLACE INTO company_info VALUES (290380, 대유, 2020-10-29)
# [2020-10-29 12:00] #0119 REPLACE INTO company_info VALUES (290120, 대유에이피, 2020-10-29)
# [2020-10-29 12:00] #0120 REPLACE INTO company_info VALUES (003310, 대주산업, 2020-10-29)
# [2020-10-29 12:00] #0121 REPLACE INTO company_info VALUES (060900, 대한그린파워, 2020-10-29)
# [2020-10-29 12:00] #0122 REPLACE INTO company_info VALUES (023910, 대한약품, 2020-10-29)
# [2020-10-29 12:00] #0123 REPLACE INTO company_info VALUES (006620, 동구바이오제약, 2020-10-29)
# [2020-10-29 12:00] #0124 REPLACE INTO company_info VALUES (099410, 동방선기, 2020-10-29)
# [2020-10-29 12:00] #0125 REPLACE INTO company_info VALUES (196490, 디에이테크놀로지, 2020-10-29)
# [2020-10-29 12:00] #0126 REPLACE INTO company_info VALUES (066900, 디에이피, 2020-10-29)
# [2020-10-29 12:00] #0127 REPLACE INTO company_info VALUES (127120, 디엔에이링크, 2020-10-29)
# [2020-10-29 12:00] #0128 REPLACE INTO company_info VALUES (092070, 디엔에프, 2020-10-29)
# [2020-10-29 12:00] #0129 REPLACE INTO company_info VALUES (039840, 디오, 2020-10-29)
# [2020-10-29 12:00] #0130 REPLACE INTO company_info VALUES (196450, 디오스텍, 2020-10-29)
# [2020-10-29 12:00] #0131 REPLACE INTO company_info VALUES (033130, 디지틀조선, 2020-10-29)
# [2020-10-29 12:00] #0132 REPLACE INTO company_info VALUES (060240, 룽투코리아, 2020-10-29)
# [2020-10-29 12:00] #0133 REPLACE INTO company_info VALUES (219420, 링크제니시스, 2020-10-29)
# [2020-10-29 12:00] #0134 REPLACE INTO company_info VALUES (086900, 메디톡스, 2020-10-29)
# [2020-10-29 12:00] #0135 REPLACE INTO company_info VALUES (021880, 메이슨캐피탈, 2020-10-29)
# [2020-10-29 12:00] #0136 REPLACE INTO company_info VALUES (327260, 메탈라이프, 2020-10-29)
# [2020-10-29 12:00] #0137 REPLACE INTO company_info VALUES (250060, 모비스, 2020-10-29)
# [2020-10-29 12:00] #0138 REPLACE INTO company_info VALUES (118990, 모트렉스, 2020-10-29)
# [2020-10-29 12:00] #0139 REPLACE INTO company_info VALUES (028040, 미래SCI, 2020-10-29)
# [2020-10-29 12:00] #0140 REPLACE INTO company_info VALUES (207760, 미스터블루, 2020-10-29)
# [2020-10-29 12:00] #0141 REPLACE INTO company_info VALUES (214610, 미코바이오메드, 2020-10-29)
# [2020-10-29 12:00] #0142 REPLACE INTO company_info VALUES (206640, 바디텍메드, 2020-10-29)
# [2020-10-29 12:00] #0143 REPLACE INTO company_info VALUES (053030, 바이넥스, 2020-10-29)
# [2020-10-29 12:00] #0144 REPLACE INTO company_info VALUES (337930, 브랜드엑스코퍼레이션, 2020-10-29)
# [2020-10-29 12:00] #0145 REPLACE INTO company_info VALUES (023600, 삼보판지, 2020-10-29)
# [2020-10-29 12:00] #0146 REPLACE INTO company_info VALUES (111870, 삼본전자, 2020-10-29)
# [2020-10-29 12:00] #0147 REPLACE INTO company_info VALUES (009300, 삼아제약, 2020-10-29)
# [2020-10-29 12:00] #0148 REPLACE INTO company_info VALUES (042940, 상지카일룸, 2020-10-29)
# [2020-10-29 12:00] #0149 REPLACE INTO company_info VALUES (100660, 서암기계공업, 2020-10-29)
# [2020-10-29 12:00] #0150 REPLACE INTO company_info VALUES (080470, 성창오토텍, 2020-10-29)
# [2020-10-29 12:00] #0151 REPLACE INTO company_info VALUES (011560, 세보엠이씨, 2020-10-29)
# [2020-10-29 12:00] #0152 REPLACE INTO company_info VALUES (258830, 세종메디칼, 2020-10-29)
# [2020-10-29 12:00] #0153 REPLACE INTO company_info VALUES (053450, 세코닉스, 2020-10-29)
# [2020-10-29 12:00] #0154 REPLACE INTO company_info VALUES (049180, 셀루메드, 2020-10-29)
# [2020-10-29 12:00] #0155 REPLACE INTO company_info VALUES (208370, 셀바스헬스케어, 2020-10-29)
# [2020-10-29 12:00] #0156 REPLACE INTO company_info VALUES (068760, 셀트리온제약, 2020-10-29)
# [2020-10-29 12:00] #0157 REPLACE INTO company_info VALUES (204630, 스튜디오산타클로스, 2020-10-29)
# [2020-10-29 12:00] #0158 REPLACE INTO company_info VALUES (013810, 스페코, 2020-10-29)
# [2020-10-29 12:00] #0159 REPLACE INTO company_info VALUES (049830, 승일, 2020-10-29)
# [2020-10-29 12:00] #0160 REPLACE INTO company_info VALUES (269620, 시스웍, 2020-10-29)
# [2020-10-29 12:00] #0161 REPLACE INTO company_info VALUES (222800, 심텍, 2020-10-29)
# [2020-10-29 12:00] #0162 REPLACE INTO company_info VALUES (010280, 쌍용정보통신, 2020-10-29)
# [2020-10-29 12:00] #0163 REPLACE INTO company_info VALUES (115480, 씨유메디칼, 2020-10-29)
# [2020-10-29 12:00] #0164 REPLACE INTO company_info VALUES (900120, 씨케이에이치, 2020-10-29)
# [2020-10-29 12:00] #0165 REPLACE INTO company_info VALUES (123860, 아나패스, 2020-10-29)
# [2020-10-29 12:00] #0166 REPLACE INTO company_info VALUES (149950, 아바텍, 2020-10-29)
# [2020-10-29 12:00] #0167 REPLACE INTO company_info VALUES (099190, 아이센스, 2020-10-29)
# [2020-10-29 12:00] #0168 REPLACE INTO company_info VALUES (040910, 아이씨디, 2020-10-29)
# [2020-10-29 12:00] #0169 REPLACE INTO company_info VALUES (068940, 아이씨케이, 2020-10-29)
# [2020-10-29 12:00] #0170 REPLACE INTO company_info VALUES (078860, 아이오케이, 2020-10-29)
# [2020-10-29 12:00] #0171 REPLACE INTO company_info VALUES (114810, 아이원스, 2020-10-29)
# [2020-10-29 12:00] #0172 REPLACE INTO company_info VALUES (031310, 아이즈비전, 2020-10-29)
# [2020-10-29 12:00] #0173 REPLACE INTO company_info VALUES (124500, 아이티센, 2020-10-29)
# [2020-10-29 12:00] #0174 REPLACE INTO company_info VALUES (260660, 알리코제약, 2020-10-29)
# [2020-10-29 12:00] #0175 REPLACE INTO company_info VALUES (096610, 알에프세미, 2020-10-29)
# [2020-10-29 12:00] #0176 REPLACE INTO company_info VALUES (061040, 알에프텍, 2020-10-29)
# [2020-10-29 12:00] #0177 REPLACE INTO company_info VALUES (310200, 애니플러스, 2020-10-29)
# [2020-10-29 12:00] #0178 REPLACE INTO company_info VALUES (065420, 에스아이리소스, 2020-10-29)
# [2020-10-29 12:00] #0179 REPLACE INTO company_info VALUES (095910, 에스에너지, 2020-10-29)
# [2020-10-29 12:00] #0180 REPLACE INTO company_info VALUES (109610, 에스와이, 2020-10-29)
# [2020-10-29 12:00] #0181 REPLACE INTO company_info VALUES (096630, 에스코넥, 2020-10-29)
# [2020-10-29 12:00] #0182 REPLACE INTO company_info VALUES (043340, 에쎈테크, 2020-10-29)
# [2020-10-29 12:00] #0183 REPLACE INTO company_info VALUES (096690, 에이루트, 2020-10-29)
# [2020-10-29 12:00] #0184 REPLACE INTO company_info VALUES (021080, 에이티넘인베스트, 2020-10-29)
# [2020-10-29 12:00] #0185 REPLACE INTO company_info VALUES (950130, 엑세스바이오, 2020-10-29)
# [2020-10-29 12:00] #0186 REPLACE INTO company_info VALUES (092870, 엑시콘, 2020-10-29)
# [2020-10-29 12:00] #0187 REPLACE INTO company_info VALUES (227950, 엔투텍, 2020-10-29)
# [2020-10-29 12:00] #0188 REPLACE INTO company_info VALUES (048830, 엔피케이, 2020-10-29)
# [2020-10-29 12:00] #0189 REPLACE INTO company_info VALUES (058630, 엠게임, 2020-10-29)
# [2020-10-29 12:00] #0190 REPLACE INTO company_info VALUES (019590, 엠벤처투자, 2020-10-29)
# [2020-10-29 12:00] #0191 REPLACE INTO company_info VALUES (097520, 엠씨넥스, 2020-10-29)
# [2020-10-29 12:00] #0192 REPLACE INTO company_info VALUES (265560, 영화테크, 2020-10-29)
# [2020-10-29 12:00] #0193 REPLACE INTO company_info VALUES (045060, 오공, 2020-10-29)
# [2020-10-29 12:00] #0194 REPLACE INTO company_info VALUES (048260, 오스템임플란트, 2020-10-29)
# [2020-10-29 12:00] #0195 REPLACE INTO company_info VALUES (049480, 오픈베이스, 2020-10-29)
# [2020-10-29 12:00] #0196 REPLACE INTO company_info VALUES (109080, 옵티시스, 2020-10-29)
# [2020-10-29 12:00] #0197 REPLACE INTO company_info VALUES (019210, 와이지-원, 2020-10-29)
# [2020-10-29 12:00] #0198 REPLACE INTO company_info VALUES (082850, 우리바이오, 2020-10-29)
# [2020-10-29 12:00] #0199 REPLACE INTO company_info VALUES (074600, 원익QnC, 2020-10-29)
# [2020-10-29 12:00] #0200 REPLACE INTO company_info VALUES (014190, 원익큐브, 2020-10-29)
# [2020-10-29 12:00] #0201 REPLACE INTO company_info VALUES (008290, 원풍물산, 2020-10-29)
# [2020-10-29 12:00] #0202 REPLACE INTO company_info VALUES (095270, 웨이브일렉트로, 2020-10-29)
# [2020-10-29 12:00] #0203 REPLACE INTO company_info VALUES (065950, 웰크론, 2020-10-29)
# [2020-10-29 12:00] #0204 REPLACE INTO company_info VALUES (036090, 위지트, 2020-10-29)
# [2020-10-29 12:00] #0205 REPLACE INTO company_info VALUES (203450, 유니온커뮤니티, 2020-10-29)
# [2020-10-29 12:00] #0206 REPLACE INTO company_info VALUES (241690, 유니테크노, 2020-10-29)
# [2020-10-29 12:00] #0207 REPLACE INTO company_info VALUES (078070, 유비쿼스홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0208 REPLACE INTO company_info VALUES (054930, 유신, 2020-10-29)
# [2020-10-29 12:00] #0209 REPLACE INTO company_info VALUES (336060, 유안타제5호스팩, 2020-10-29)
# [2020-10-29 12:00] #0210 REPLACE INTO company_info VALUES (331380, 유진스팩5호, 2020-10-29)
# [2020-10-29 12:00] #0211 REPLACE INTO company_info VALUES (178780, 유테크, 2020-10-29)
# [2020-10-29 12:00] #0212 REPLACE INTO company_info VALUES (179900, 유티아이, 2020-10-29)
# [2020-10-29 12:00] #0213 REPLACE INTO company_info VALUES (047560, 이스트소프트, 2020-10-29)
# [2020-10-29 12:00] #0214 REPLACE INTO company_info VALUES (900110, 이스트아시아홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0215 REPLACE INTO company_info VALUES (123570, 이엠넷, 2020-10-29)
# [2020-10-29 12:00] #0216 REPLACE INTO company_info VALUES (353810, 이지바이오, 2020-10-29)
# [2020-10-29 12:00] #0217 REPLACE INTO company_info VALUES (090850, 이지웰, 2020-10-29)
# [2020-10-29 12:00] #0218 REPLACE INTO company_info VALUES (079950, 인베니아, 2020-10-29)
# [2020-10-29 12:00] #0219 REPLACE INTO company_info VALUES (064290, 인텍플러스, 2020-10-29)
# [2020-10-29 12:00] #0220 REPLACE INTO company_info VALUES (254120, 자비스, 2020-10-29)
# [2020-10-29 12:00] #0221 REPLACE INTO company_info VALUES (234920, 자이글, 2020-10-29)
# [2020-10-29 12:00] #0222 REPLACE INTO company_info VALUES (174880, 장원테크, 2020-10-29)
# [2020-10-29 12:00] #0223 REPLACE INTO company_info VALUES (040420, 정상제이엘에스, 2020-10-29)
# [2020-10-29 12:00] #0224 REPLACE INTO company_info VALUES (079370, 제우스, 2020-10-29)
# [2020-10-29 12:00] #0225 REPLACE INTO company_info VALUES (094970, 제이엠티, 2020-10-29)
# [2020-10-29 12:00] #0226 REPLACE INTO company_info VALUES (058420, 제이웨이, 2020-10-29)
# [2020-10-29 12:00] #0227 REPLACE INTO company_info VALUES (023440, 제일제강, 2020-10-29)
# [2020-10-29 12:00] #0228 REPLACE INTO company_info VALUES (080220, 제주반도체, 2020-10-29)
# [2020-10-29 12:00] #0229 REPLACE INTO company_info VALUES (082270, 젬백스, 2020-10-29)
# [2020-10-29 12:00] #0230 REPLACE INTO company_info VALUES (034940, 조아제약, 2020-10-29)
# [2020-10-29 12:00] #0231 REPLACE INTO company_info VALUES (036930, 주성엔지니어링, 2020-10-29)
# [2020-10-29 12:00] #0232 REPLACE INTO company_info VALUES (119850, 지엔씨에너지, 2020-10-29)
# [2020-10-29 12:00] #0233 REPLACE INTO company_info VALUES (065060, 지엔코, 2020-10-29)
# [2020-10-29 12:00] #0234 REPLACE INTO company_info VALUES (071850, 캐스텍코리아, 2020-10-29)
# [2020-10-29 12:00] #0235 REPLACE INTO company_info VALUES (342550, 케이비제20호스팩, 2020-10-29)
# [2020-10-29 12:00] #0236 REPLACE INTO company_info VALUES (054410, 케이피티유, 2020-10-29)
# [2020-10-29 12:00] #0237 REPLACE INTO company_info VALUES (274090, 켄코아에어로스페이스, 2020-10-29)
# [2020-10-29 12:00] #0238 REPLACE INTO company_info VALUES (078650, 코렌, 2020-10-29)
# [2020-10-29 12:00] #0239 REPLACE INTO company_info VALUES (282880, 코윈테크, 2020-10-29)
# [2020-10-29 12:00] #0240 REPLACE INTO company_info VALUES (126600, 코프라, 2020-10-29)
# [2020-10-29 12:00] #0241 REPLACE INTO company_info VALUES (139670, 키네마스터, 2020-10-29)
# [2020-10-29 12:00] #0242 REPLACE INTO company_info VALUES (045340, 토탈소프트, 2020-10-29)
# [2020-10-29 12:00] #0243 REPLACE INTO company_info VALUES (079970, 투비소프트, 2020-10-29)
# [2020-10-29 12:00] #0244 REPLACE INTO company_info VALUES (105550, 트루윈, 2020-10-29)
# [2020-10-29 12:00] #0245 REPLACE INTO company_info VALUES (026150, 특수건설, 2020-10-29)
# [2020-10-29 12:00] #0246 REPLACE INTO company_info VALUES (246710, 티앤알바이오팹, 2020-10-29)
# [2020-10-29 12:00] #0247 REPLACE INTO company_info VALUES (131290, 티에스이, 2020-10-29)
# [2020-10-29 12:00] #0248 REPLACE INTO company_info VALUES (037070, 파세코, 2020-10-29)
# [2020-10-29 12:00] #0249 REPLACE INTO company_info VALUES (065690, 파커스, 2020-10-29)
# [2020-10-29 12:00] #0250 REPLACE INTO company_info VALUES (225590, 패션플랫폼, 2020-10-29)
# [2020-10-29 12:00] #0251 REPLACE INTO company_info VALUES (005670, 푸드웰, 2020-10-29)
# [2020-10-29 12:00] #0252 REPLACE INTO company_info VALUES (203690, 프로스테믹스, 2020-10-29)
# [2020-10-29 12:00] #0253 REPLACE INTO company_info VALUES (032580, 피델릭스, 2020-10-29)
# [2020-10-29 12:00] #0254 REPLACE INTO company_info VALUES (024850, 피에스엠씨, 2020-10-29)
# [2020-10-29 12:00] #0255 REPLACE INTO company_info VALUES (341160, 하나금융15호스팩, 2020-10-29)
# [2020-10-29 12:00] #0256 REPLACE INTO company_info VALUES (221840, 하이즈항공, 2020-10-29)
# [2020-10-29 12:00] #0257 REPLACE INTO company_info VALUES (222980, 한국맥널티, 2020-10-29)
# [2020-10-29 12:00] #0258 REPLACE INTO company_info VALUES (050540, 한국코퍼레이션, 2020-10-29)
# [2020-10-29 12:00] #0259 REPLACE INTO company_info VALUES (078350, 한양디지텍, 2020-10-29)
# [2020-10-29 12:00] #0260 REPLACE INTO company_info VALUES (123840, 한일진공, 2020-10-29)
# [2020-10-29 12:00] #0261 REPLACE INTO company_info VALUES (007770, 한일화학, 2020-10-29)
# [2020-10-29 12:00] #0262 REPLACE INTO company_info VALUES (102210, 해덕파워웨이, 2020-10-29)
# [2020-10-29 12:00] #0263 REPLACE INTO company_info VALUES (048410, 현대바이오, 2020-10-29)
# [2020-10-29 12:00] #0264 REPLACE INTO company_info VALUES (039610, 화성밸브, 2020-10-29)
# [2020-10-29 12:00] #0265 REPLACE INTO company_info VALUES (090710, 휴림로봇, 2020-10-29)
# [2020-10-29 12:00] #0266 REPLACE INTO company_info VALUES (115160, 휴맥스, 2020-10-29)
# [2020-10-29 12:00] #0267 REPLACE INTO company_info VALUES (084110, 휴온스글로벌, 2020-10-29)
# [2020-10-29 12:00] #0268 REPLACE INTO company_info VALUES (244880, 나눔테크, 2020-10-29)
# [2020-10-29 12:00] #0269 REPLACE INTO company_info VALUES (323350, 다원넥스뷰, 2020-10-29)
# [2020-10-29 12:00] #0270 REPLACE INTO company_info VALUES (086080, 다이노나, 2020-10-29)
# [2020-10-29 12:00] #0271 REPLACE INTO company_info VALUES (271850, 다이오진, 2020-10-29)
# [2020-10-29 12:00] #0272 REPLACE INTO company_info VALUES (067370, 선바이오, 2020-10-29)
# [2020-10-29 12:00] #0273 REPLACE INTO company_info VALUES (270210, 에스알바이오텍, 2020-10-29)
# [2020-10-29 12:00] #0274 REPLACE INTO company_info VALUES (276240, 엘리비젼, 2020-10-29)
# [2020-10-29 12:00] #0275 REPLACE INTO company_info VALUES (221800, 유투바이오, 2020-10-29)
# [2020-10-29 12:00] #0276 REPLACE INTO company_info VALUES (336040, 이도바이오, 2020-10-29)
# [2020-10-29 12:00] #0277 REPLACE INTO company_info VALUES (120780, 전우정밀, 2020-10-29)
# [2020-10-29 12:00] #0278 REPLACE INTO company_info VALUES (314130, 지놈앤컴퍼니, 2020-10-29)
# [2020-10-29 12:00] #0279 REPLACE INTO company_info VALUES (250030, 진코스텍, 2020-10-29)
# [2020-10-29 12:00] #0280 REPLACE INTO company_info VALUES (136660, 큐엠씨, 2020-10-29)
# [2020-10-29 12:00] #0281 REPLACE INTO company_info VALUES (309900, 티티씨디펜스, 2020-10-29)
# [2020-10-29 12:00] #0282 REPLACE INTO company_info VALUES (354230, 폭스소프트, 2020-10-29)
# [2020-10-29 12:00] #0283 REPLACE INTO company_info VALUES (079160, CJ CGV, 2020-10-29)
# [2020-10-29 12:00] #0284 REPLACE INTO company_info VALUES (089470, HDC현대EP, 2020-10-29)
# [2020-10-29 12:00] #0285 REPLACE INTO company_info VALUES (096760, JW홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0286 REPLACE INTO company_info VALUES (105560, KB금융, 2020-10-29)
# [2020-10-29 12:00] #0287 REPLACE INTO company_info VALUES (001380, SG충방, 2020-10-29)
# [2020-10-29 12:00] #0288 REPLACE INTO company_info VALUES (014280, 금강공업, 2020-10-29)
# [2020-10-29 12:00] #0289 REPLACE INTO company_info VALUES (002990, 금호산업, 2020-10-29)
# [2020-10-29 12:00] #0290 REPLACE INTO company_info VALUES (001210, 금호전기, 2020-10-29)
# [2020-10-29 12:00] #0291 REPLACE INTO company_info VALUES (024110, 기업은행, 2020-10-29)
# [2020-10-29 12:00] #0292 REPLACE INTO company_info VALUES (008350, 남선알미늄, 2020-10-29)
# [2020-10-29 12:00] #0293 REPLACE INTO company_info VALUES (004270, 남성, 2020-10-29)
# [2020-10-29 12:00] #0294 REPLACE INTO company_info VALUES (251270, 넷마블, 2020-10-29)
# [2020-10-29 12:00] #0295 REPLACE INTO company_info VALUES (006370, 대구백화점, 2020-10-29)
# [2020-10-29 12:00] #0296 REPLACE INTO company_info VALUES (047040, 대우건설, 2020-10-29)
# [2020-10-29 12:00] #0297 REPLACE INTO company_info VALUES (003220, 대원제약, 2020-10-29)
# [2020-10-29 12:00] #0298 REPLACE INTO company_info VALUES (001070, 대한방직, 2020-10-29)
# [2020-10-29 12:00] #0299 REPLACE INTO company_info VALUES (001790, 대한제당, 2020-10-29)
# [2020-10-29 12:00] #0300 REPLACE INTO company_info VALUES (005880, 대한해운, 2020-10-29)
# [2020-10-29 12:00] #0301 REPLACE INTO company_info VALUES (016090, 대현, 2020-10-29)
# [2020-10-29 12:00] #0302 REPLACE INTO company_info VALUES (024900, 덕양산업, 2020-10-29)
# [2020-10-29 12:00] #0303 REPLACE INTO company_info VALUES (018500, 동원금속, 2020-10-29)
# [2020-10-29 12:00] #0304 REPLACE INTO company_info VALUES (042670, 두산인프라코어, 2020-10-29)
# [2020-10-29 12:00] #0305 REPLACE INTO company_info VALUES (024090, 디씨엠, 2020-10-29)
# [2020-10-29 12:00] #0306 REPLACE INTO company_info VALUES (007340, 디티알오토모티브, 2020-10-29)
# [2020-10-29 12:00] #0307 REPLACE INTO company_info VALUES (000400, 롯데손해보험, 2020-10-29)
# [2020-10-29 12:00] #0308 REPLACE INTO company_info VALUES (005300, 롯데칠성음료, 2020-10-29)
# [2020-10-29 12:00] #0309 REPLACE INTO company_info VALUES (071840, 롯데하이마트, 2020-10-29)
# [2020-10-29 12:00] #0310 REPLACE INTO company_info VALUES (085620, 미래에셋생명, 2020-10-29)
# [2020-10-29 12:00] #0311 REPLACE INTO company_info VALUES (107590, 미원홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0312 REPLACE INTO company_info VALUES (035150, 백산, 2020-10-29)
# [2020-10-29 12:00] #0313 REPLACE INTO company_info VALUES (002760, 보락, 2020-10-29)
# [2020-10-29 12:00] #0314 REPLACE INTO company_info VALUES (003960, 사조대림, 2020-10-29)
# [2020-10-29 12:00] #0315 REPLACE INTO company_info VALUES (008040, 사조동아원, 2020-10-29)
# [2020-10-29 12:00] #0316 REPLACE INTO company_info VALUES (021050, 서원, 2020-10-29)
# [2020-10-29 12:00] #0317 REPLACE INTO company_info VALUES (004360, 세방, 2020-10-29)
# [2020-10-29 12:00] #0318 REPLACE INTO company_info VALUES (058650, 세아홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0319 REPLACE INTO company_info VALUES (067830, 세이브존I&C, 2020-10-29)
# [2020-10-29 12:00] #0320 REPLACE INTO company_info VALUES (006880, 신송홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0321 REPLACE INTO company_info VALUES (002700, 신일전자, 2020-10-29)
# [2020-10-29 12:00] #0322 REPLACE INTO company_info VALUES (004770, 써니전자, 2020-10-29)
# [2020-10-29 12:00] #0323 REPLACE INTO company_info VALUES (122900, 아이마켓코리아, 2020-10-29)
# [2020-10-29 12:00] #0324 REPLACE INTO company_info VALUES (003560, 아이에이치큐, 2020-10-29)
# [2020-10-29 12:00] #0325 REPLACE INTO company_info VALUES (078520, 에이블씨엔씨, 2020-10-29)
# [2020-10-29 12:00] #0326 REPLACE INTO company_info VALUES (036570, 엔씨소프트, 2020-10-29)
# [2020-10-29 12:00] #0327 REPLACE INTO company_info VALUES (014440, 영보화학, 2020-10-29)
# [2020-10-29 12:00] #0328 REPLACE INTO company_info VALUES (003520, 영진약품, 2020-10-29)
# [2020-10-29 12:00] #0329 REPLACE INTO company_info VALUES (000670, 영풍, 2020-10-29)
# [2020-10-29 12:00] #0330 REPLACE INTO company_info VALUES (015360, 예스코홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0331 REPLACE INTO company_info VALUES (047400, 유니온머티리얼, 2020-10-29)
# [2020-10-29 12:00] #0332 REPLACE INTO company_info VALUES (000220, 유유제약, 2020-10-29)
# [2020-10-29 12:00] #0333 REPLACE INTO company_info VALUES (000100, 유한양행, 2020-10-29)
# [2020-10-29 12:00] #0334 REPLACE INTO company_info VALUES (139480, 이마트, 2020-10-29)
# [2020-10-29 12:00] #0335 REPLACE INTO company_info VALUES (005950, 이수화학, 2020-10-29)
# [2020-10-29 12:00] #0336 REPLACE INTO company_info VALUES (015020, 이스타코, 2020-10-29)
# [2020-10-29 12:00] #0337 REPLACE INTO company_info VALUES (034590, 인천도시가스, 2020-10-29)
# [2020-10-29 12:00] #0338 REPLACE INTO company_info VALUES (008500, 일정실업, 2020-10-29)
# [2020-10-29 12:00] #0339 REPLACE INTO company_info VALUES (001630, 종근당홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0340 REPLACE INTO company_info VALUES (013870, 지엠비코리아, 2020-10-29)
# [2020-10-29 12:00] #0341 REPLACE INTO company_info VALUES (011000, 진원생명과학, 2020-10-29)
# [2020-10-29 12:00] #0342 REPLACE INTO company_info VALUES (109070, 컨버즈, 2020-10-29)
# [2020-10-29 12:00] #0343 REPLACE INTO company_info VALUES (281820, 케이씨텍, 2020-10-29)
# [2020-10-29 12:00] #0344 REPLACE INTO company_info VALUES (007810, 코리아써키트, 2020-10-29)
# [2020-10-29 12:00] #0345 REPLACE INTO company_info VALUES (005420, 코스모화학, 2020-10-29)
# [2020-10-29 12:00] #0346 REPLACE INTO company_info VALUES (071950, 코아스, 2020-10-29)
# [2020-10-29 12:00] #0347 REPLACE INTO company_info VALUES (138490, 코오롱플라스틱, 2020-10-29)
# [2020-10-29 12:00] #0348 REPLACE INTO company_info VALUES (192400, 쿠쿠홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0349 REPLACE INTO company_info VALUES (015590, 큐로, 2020-10-29)
# [2020-10-29 12:00] #0350 REPLACE INTO company_info VALUES (084870, 티비에이치글로벌, 2020-10-29)
# [2020-10-29 12:00] #0351 REPLACE INTO company_info VALUES (007630, 폴루스바이오팜, 2020-10-29)
# [2020-10-29 12:00] #0352 REPLACE INTO company_info VALUES (019490, 하이트론씨스템즈, 2020-10-29)
# [2020-10-29 12:00] #0353 REPLACE INTO company_info VALUES (071050, 한국금융지주, 2020-10-29)
# [2020-10-29 12:00] #0354 REPLACE INTO company_info VALUES (006200, 한국전자홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0355 REPLACE INTO company_info VALUES (161390, 한국타이어앤테크놀로지, 2020-10-29)
# [2020-10-29 12:00] #0356 REPLACE INTO company_info VALUES (000240, 한국테크놀로지그룹, 2020-10-29)
# [2020-10-29 12:00] #0357 REPLACE INTO company_info VALUES (034830, 한국토지신탁, 2020-10-29)
# [2020-10-29 12:00] #0358 REPLACE INTO company_info VALUES (007280, 한국특수형강, 2020-10-29)
# [2020-10-29 12:00] #0359 REPLACE INTO company_info VALUES (300720, 한일시멘트, 2020-10-29)
# [2020-10-29 12:00] #0360 REPLACE INTO company_info VALUES (009830, 한화솔루션, 2020-10-29)
# [2020-10-29 12:00] #0361 REPLACE INTO company_info VALUES (101530, 해태제과식품, 2020-10-29)
# [2020-10-29 12:00] #0362 REPLACE INTO company_info VALUES (322000, 현대에너지솔루션, 2020-10-29)
# [2020-10-29 12:00] #0363 REPLACE INTO company_info VALUES (126560, 현대에이치씨엔, 2020-10-29)
# [2020-10-29 12:00] #0364 REPLACE INTO company_info VALUES (011210, 현대위아, 2020-10-29)
# [2020-10-29 12:00] #0365 REPLACE INTO company_info VALUES (227840, 현대코퍼레이션홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0366 REPLACE INTO company_info VALUES (008770, 호텔신라, 2020-10-29)
# [2020-10-29 12:00] #0367 REPLACE INTO company_info VALUES (006060, 화승인더스트리, 2020-10-29)
# [2020-10-29 12:00] #0368 REPLACE INTO company_info VALUES (000850, 화천기공, 2020-10-29)
# [2020-10-29 12:00] #0369 REPLACE INTO company_info VALUES (016580, 환인제약, 2020-10-29)
# [2020-10-29 12:00] #0370 REPLACE INTO company_info VALUES (004800, 효성, 2020-10-29)
# [2020-10-29 12:00] #0371 REPLACE INTO company_info VALUES (298000, 효성화학, 2020-10-29)
# [2020-10-29 12:00] #0372 REPLACE INTO company_info VALUES (003280, 흥아해운, 2020-10-29)
# [2020-10-29 12:00] #0373 REPLACE INTO company_info VALUES (054620, APS홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0374 REPLACE INTO company_info VALUES (035760, CJ ENM, 2020-10-29)
# [2020-10-29 12:00] #0375 REPLACE INTO company_info VALUES (058820, CMG제약, 2020-10-29)
# [2020-10-29 12:00] #0376 REPLACE INTO company_info VALUES (065770, CS, 2020-10-29)
# [2020-10-29 12:00] #0377 REPLACE INTO company_info VALUES (083660, CSA 코스믹, 2020-10-29)
# [2020-10-29 12:00] #0378 REPLACE INTO company_info VALUES (037370, EG, 2020-10-29)
# [2020-10-29 12:00] #0379 REPLACE INTO company_info VALUES (036640, HRS, 2020-10-29)
# [2020-10-29 12:00] #0380 REPLACE INTO company_info VALUES (030190, NICE평가정보, 2020-10-29)
# [2020-10-29 12:00] #0381 REPLACE INTO company_info VALUES (024940, PN풍년, 2020-10-29)
# [2020-10-29 12:00] #0382 REPLACE INTO company_info VALUES (036120, SCI평가정보, 2020-10-29)
# [2020-10-29 12:00] #0383 REPLACE INTO company_info VALUES (048550, SM C&C, 2020-10-29)
# [2020-10-29 12:00] #0384 REPLACE INTO company_info VALUES (038340, UCI, 2020-10-29)
# [2020-10-29 12:00] #0385 REPLACE INTO company_info VALUES (192410, 감마누, 2020-10-29)
# [2020-10-29 12:00] #0386 REPLACE INTO company_info VALUES (217730, 강스템바이오텍, 2020-10-29)
# [2020-10-29 12:00] #0387 REPLACE INTO company_info VALUES (063080, 게임빌, 2020-10-29)
# [2020-10-29 12:00] #0388 REPLACE INTO company_info VALUES (044480, 경남바이오파마, 2020-10-29)
# [2020-10-29 12:00] #0389 REPLACE INTO company_info VALUES (223310, 경남제약헬스케어, 2020-10-29)
# [2020-10-29 12:00] #0390 REPLACE INTO company_info VALUES (098460, 고영, 2020-10-29)
# [2020-10-29 12:00] #0391 REPLACE INTO company_info VALUES (014200, 광림, 2020-10-29)
# [2020-10-29 12:00] #0392 REPLACE INTO company_info VALUES (006050, 국영지앤엠, 2020-10-29)
# [2020-10-29 12:00] #0393 REPLACE INTO company_info VALUES (039860, 나노엔텍, 2020-10-29)
# [2020-10-29 12:00] #0394 REPLACE INTO company_info VALUES (138610, 나이벡, 2020-10-29)
# [2020-10-29 12:00] #0395 REPLACE INTO company_info VALUES (091590, 남화토건, 2020-10-29)
# [2020-10-29 12:00] #0396 REPLACE INTO company_info VALUES (092730, 네오팜, 2020-10-29)
# [2020-10-29 12:00] #0397 REPLACE INTO company_info VALUES (089140, 넥스턴, 2020-10-29)
# [2020-10-29 12:00] #0398 REPLACE INTO company_info VALUES (217270, 넵튠, 2020-10-29)
# [2020-10-29 12:00] #0399 REPLACE INTO company_info VALUES (194700, 노바렉스, 2020-10-29)
# [2020-10-29 12:00] #0400 REPLACE INTO company_info VALUES (065560, 녹원씨엔아이, 2020-10-29)
# [2020-10-29 12:00] #0401 REPLACE INTO company_info VALUES (040160, 누리텔레콤, 2020-10-29)
# [2020-10-29 12:00] #0402 REPLACE INTO company_info VALUES (144960, 뉴파워프라즈마, 2020-10-29)
# [2020-10-29 12:00] #0403 REPLACE INTO company_info VALUES (104040, 대성파인텍, 2020-10-29)
# [2020-10-29 12:00] #0404 REPLACE INTO company_info VALUES (045390, 대아티아이, 2020-10-29)
# [2020-10-29 12:00] #0405 REPLACE INTO company_info VALUES (078600, 대주전자재료, 2020-10-29)
# [2020-10-29 12:00] #0406 REPLACE INTO company_info VALUES (096350, 대창솔루션, 2020-10-29)
# [2020-10-29 12:00] #0407 REPLACE INTO company_info VALUES (213420, 덕산네오룩스, 2020-10-29)
# [2020-10-29 12:00] #0408 REPLACE INTO company_info VALUES (194480, 데브시스터즈, 2020-10-29)
# [2020-10-29 12:00] #0409 REPLACE INTO company_info VALUES (088130, 동아엘텍, 2020-10-29)
# [2020-10-29 12:00] #0410 REPLACE INTO company_info VALUES (030350, 드래곤플라이, 2020-10-29)
# [2020-10-29 12:00] #0411 REPLACE INTO company_info VALUES (214680, 디알텍, 2020-10-29)
# [2020-10-29 12:00] #0412 REPLACE INTO company_info VALUES (134580, 디엠티, 2020-10-29)
# [2020-10-29 12:00] #0413 REPLACE INTO company_info VALUES (131180, 딜리, 2020-10-29)
# [2020-10-29 12:00] #0414 REPLACE INTO company_info VALUES (033600, 럭슬, 2020-10-29)
# [2020-10-29 12:00] #0415 REPLACE INTO company_info VALUES (060300, 레드로버, 2020-10-29)
# [2020-10-29 12:00] #0416 REPLACE INTO company_info VALUES (038390, 레드캡투어, 2020-10-29)
# [2020-10-29 12:00] #0417 REPLACE INTO company_info VALUES (228850, 레이언스, 2020-10-29)
# [2020-10-29 12:00] #0418 REPLACE INTO company_info VALUES (215100, 로보로보, 2020-10-29)
# [2020-10-29 12:00] #0419 REPLACE INTO company_info VALUES (005990, 매일홀딩스, 2020-10-29)
# [2020-10-29 12:00] #0420 REPLACE INTO company_info VALUES (100590, 머큐리, 2020-10-29)
# [2020-10-29 12:00] #0421 REPLACE INTO company_info VALUES (014100, 메디앙스, 2020-10-29)
# [2020-10-29 12:00] #0422 REPLACE INTO company_info VALUES (059210, 메타바이오메드, 2020-10-29)
# [2020-10-29 12:00] #0423 REPLACE INTO company_info VALUES (058110, 멕아이씨에스, 2020-10-29)
# [2020-10-29 12:00] #0424 REPLACE INTO company_info VALUES (080160, 모두투어, 2020-10-29)
# [2020-10-29 12:00] #0425 REPLACE INTO company_info VALUES (001810, 무림SP, 2020-10-29)
# [2020-10-29 12:00] #0426 REPLACE INTO company_info VALUES (328380, 미래에셋대우스팩3호, 2020-10-29)
# [2020-10-29 12:00] #0427 REPLACE INTO company_info VALUES (100790, 미래에셋벤처투자, 2020-10-29)
# [2020-10-29 12:00] #0428 REPLACE INTO company_info VALUES (059090, 미코, 2020-10-29)
# [2020-10-29 12:00] #0429 REPLACE INTO company_info VALUES (301300, 바이브컴퍼니, 2020-10-29)
# [2020-10-29 12:00] #0430 REPLACE INTO company_info VALUES (323990, 박셀바이오, 2020-10-29)
# [2020-10-29 12:00] #0431 REPLACE INTO company_info VALUES (008470, 부스타, 2020-10-29)
# [2020-10-29 12:00] #0432 REPLACE INTO company_info VALUES (138580, 비즈니스온, 2020-10-29)
# [2020-10-29 12:00] #0433 REPLACE INTO company_info VALUES (032850, 비트컴퓨터, 2020-10-29)
# [2020-10-29 12:00] #0434 REPLACE INTO company_info VALUES (143240, 사람인에이치알, 2020-10-29)
# [2020-10-29 12:00] #0435 REPLACE INTO company_info VALUES (014970, 삼륭물산, 2020-10-29)
# [2020-10-29 12:00] #0436 REPLACE INTO company_info VALUES (225190, 삼양옵틱스, 2020-10-29)
# [2020-10-29 12:00] #0437 REPLACE INTO company_info VALUES (065570, 삼영이엔씨, 2020-10-29)
# [2020-10-29 12:00] #0438 REPLACE INTO company_info VALUES (032280, 삼일, 2020-10-29)
# [2020-10-29 12:00] #0439 REPLACE INTO company_info VALUES (002290, 삼일기업공사, 2020-10-29)
# [2020-10-29 12:00] #0440 REPLACE INTO company_info VALUES (037460, 삼지전자, 2020-10-29)
# [2020-10-29 12:00] #0441 REPLACE INTO company_info VALUES (032750, 삼진, 2020-10-29)
# [2020-10-29 12:00] #0442 REPLACE INTO company_info VALUES (046390, 삼화네트웍스, 2020-10-29)
# [2020-10-29 12:00] #0443 REPLACE INTO company_info VALUES (027580, 상보, 2020-10-29)
# [2020-10-29 12:00] #0444 REPLACE INTO company_info VALUES (091580, 상신이디피, 2020-10-29)
# [2020-10-29 12:00] #0445 REPLACE INTO company_info VALUES (038070, 서린바이오, 2020-10-29)
# [2020-10-29 12:00] #0446 REPLACE INTO company_info VALUES (019770, 서연탑메탈, 2020-10-29)
# [2020-10-29 12:00] #0447 REPLACE INTO company_info VALUES (092190, 서울바이오시스, 2020-10-29)
# [2020-10-29 12:00] #0448 REPLACE INTO company_info VALUES (065710, 서호전기, 2020-10-29)
# [2020-10-29 12:00] #0449 REPLACE INTO company_info VALUES (015750, 성우하이텍, 2020-10-29)
# [2020-10-29 12:00] #0450 REPLACE INTO company_info VALUES (148150, 세경하이테크, 2020-10-29)
# [2020-10-29 12:00] #0451 REPLACE INTO company_info VALUES (017510, 세명전기, 2020-10-29)
# [2020-10-29 12:00] #0452 REPLACE INTO company_info VALUES (108860, 셀바스AI, 2020-10-29)
# [2020-10-29 12:00] #0453 REPLACE INTO company_info VALUES (066910, 손오공, 2020-10-29)
# [2020-10-29 12:00] #0454 REPLACE INTO company_info VALUES (154040, 솔루에타, 2020-10-29)
# [2020-10-29 12:00] #0455 REPLACE INTO company_info VALUES (084180, 수성, 2020-10-29)
# [2020-10-29 12:00] #0456 REPLACE INTO company_info VALUES (236200, 슈프리마, 2020-10-29)
# [2020-10-29 12:00] #0457 REPLACE INTO company_info VALUES (253450, 스튜디오드래곤, 2020-10-29)
# [2020-10-29 12:00] #0458 REPLACE INTO company_info VALUES (025870, 신라에스지, 2020-10-29)
# [2020-10-29 12:00] #0459 REPLACE INTO company_info VALUES (215600, 신라젠, 2020-10-29)
# [2020-10-29 12:00] #0460 REPLACE INTO company_info VALUES (323280, 신영스팩5호, 2020-10-29)
# [2020-10-29 12:00] #0461 REPLACE INTO company_info VALUES (333050, 신한제6호스팩, 2020-10-29)
# [2020-10-29 12:00] #0462 REPLACE INTO company_info VALUES (013990, 아가방컴퍼니, 2020-10-29)
# [2020-10-29 12:00] #0463 REPLACE INTO company_info VALUES (050320, 아래스, 2020-10-29)
# [2020-10-29 12:00] #0464 REPLACE INTO company_info VALUES (052710, 아모텍, 2020-10-29)
# [2020-10-29 12:00] #0465 REPLACE INTO company_info VALUES (092040, 아미코젠, 2020-10-29)
# [2020-10-29 12:00] #0466 REPLACE INTO company_info VALUES (038880, 아이에이, 2020-10-29)
# [2020-10-29 12:00] #0467 REPLACE INTO company_info VALUES (123010, 아이에이네트웍스, 2020-10-29)
# [2020-10-29 12:00] #0468 REPLACE INTO company_info VALUES (052770, 아이톡시, 2020-10-29)
# [2020-10-29 12:00] #0469 REPLACE INTO company_info VALUES (290740, 액트로, 2020-10-29)
# [2020-10-29 12:00] #0470 REPLACE INTO company_info VALUES (073070, 에스모, 2020-10-29)
# [2020-10-29 12:00] #0471 REPLACE INTO company_info VALUES (275630, 에스에스알, 2020-10-29)
# [2020-10-29 12:00] #0472 REPLACE INTO company_info VALUES (306040, 에스제이그룹, 2020-10-29)
# [2020-10-29 12:00] #0473 REPLACE INTO company_info VALUES (080440, 에스제이케이, 2020-10-29)
# [2020-10-29 12:00] #0474 REPLACE INTO company_info VALUES (237690, 에스티팜, 2020-10-29)
# [2020-10-29 12:00] #0475 REPLACE INTO company_info VALUES (138360, 에이씨티, 2020-10-29)
# [2020-10-29 12:00] #0476 REPLACE INTO company_info VALUES (073540, 에프알텍, 2020-10-29)
# [2020-10-29 12:00] #0477 REPLACE INTO company_info VALUES (036810, 에프에스티, 2020-10-29)
# [2020-10-29 12:00] #0478 REPLACE INTO company_info VALUES (101400, 엔시트론, 2020-10-29)
# [2020-10-29 12:00] #0479 REPLACE INTO company_info VALUES (319400, 엔에이치스팩14호, 2020-10-29)
# [2020-10-29 12:00] #0480 REPLACE INTO company_info VALUES (007530, 영신금속, 2020-10-29)
# [2020-10-29 12:00] #0481 REPLACE INTO company_info VALUES (036000, 예림당, 2020-10-29)
# [2020-10-29 12:00] #0482 REPLACE INTO company_info VALUES (046120, 오르비텍, 2020-10-29)
# [2020-10-29 12:00] #0483 REPLACE INTO company_info VALUES (241790, 오션브릿지, 2020-10-29)
# [2020-10-29 12:00] #0484 REPLACE INTO company_info VALUES (073560, 우리손에프앤지, 2020-10-29)
# [2020-10-29 12:00] #0485 REPLACE INTO company_info VALUES (066590, 우수AMS, 2020-10-29)
# [2020-10-29 12:00] #0486 REPLACE INTO company_info VALUES (012620, 원일특강, 2020-10-29)
# [2020-10-29 12:00] #0487 REPLACE INTO company_info VALUES (192390, 윈하이텍, 2020-10-29)
# [2020-10-29 12:00] #0488 REPLACE INTO company_info VALUES (313760, 윌링스, 2020-10-29)
# [2020-10-29 12:00] #0489 REPLACE INTO company_info VALUES (086390, 유니테스트, 2020-10-29)
# [2020-10-29 12:00] #0490 REPLACE INTO company_info VALUES (206650, 유바이오로직스, 2020-10-29)
# [2020-10-29 12:00] #0491 REPLACE INTO company_info VALUES (340360, 유안타제6호스팩, 2020-10-29)
# [2020-10-29 12:00] #0492 REPLACE INTO company_info VALUES (191410, 육일씨엔에쓰, 2020-10-29)
# [2020-10-29 12:00] #0493 REPLACE INTO company_info VALUES (067920, 이글루시큐리티, 2020-10-29)
# [2020-10-29 12:00] #0494 REPLACE INTO company_info VALUES (044960, 이글벳, 2020-10-29)
# [2020-10-29 12:00] #0495 REPLACE INTO company_info VALUES (088390, 이녹스, 2020-10-29)
# [2020-10-29 12:00] #0496 REPLACE INTO company_info VALUES (264850, 이랜시스, 2020-10-29)
# [2020-10-29 12:00] #0497 REPLACE INTO company_info VALUES (349720, 이베스트스팩5호, 2020-10-29)
# [2020-10-29 12:00] #0498 REPLACE INTO company_info VALUES (052190, 이에스에이, 2020-10-29)
# [2020-10-29 12:00] #0499 REPLACE INTO company_info VALUES (083470, 이엠앤아이, 2020-10-29)
# [2020-10-29 12:00] #0500 REPLACE INTO company_info VALUES (091120, 이엠텍, 2020-10-29)
# [2020-10-29 12:00] #0501 REPLACE INTO company_info VALUES (181340, 이즈미디어, 2020-10-29)
# [2020-10-29 12:00] #0502 REPLACE INTO company_info VALUES (099750, 이지케어텍, 2020-10-29)
# [2020-10-29 12:00] #0503 REPLACE INTO company_info VALUES (060150, 인선이엔티, 2020-10-29)
# [2020-10-29 12:00] #0504 REPLACE INTO company_info VALUES (175140, 인포마크, 2020-10-29)
# [2020-10-29 12:00] #0505 REPLACE INTO company_info VALUES (115310, 인포바인, 2020-10-29)
# [2020-10-29 12:00] #0506 REPLACE INTO company_info VALUES (039290, 인포뱅크, 2020-10-29)
# [2020-10-29 12:00] #0507 REPLACE INTO company_info VALUES (049550, 잉크테크, 2020-10-29)
# [2020-10-29 12:00] #0508 REPLACE INTO company_info VALUES (110020, 전진바이오팜, 2020-10-29)
# [2020-10-29 12:00] #0509 REPLACE INTO company_info VALUES (208140, 정다운, 2020-10-29)
# [2020-10-29 12:00] #0510 REPLACE INTO company_info VALUES (225220, 제놀루션, 2020-10-29)
# [2020-10-29 12:00] #0511 REPLACE INTO company_info VALUES (090470, 제이스텍, 2020-10-29)
# [2020-10-29 12:00] #0512 REPLACE INTO company_info VALUES (052670, 제일바이오, 2020-10-29)
# [2020-10-29 12:00] #0513 REPLACE INTO company_info VALUES (041590, 젬백스지오, 2020-10-29)
# [2020-10-29 12:00] #0514 REPLACE INTO company_info VALUES (101730, 조이맥스, 2020-10-29)
# [2020-10-29 12:00] #0515 REPLACE INTO company_info VALUES (239340, 줌인터넷, 2020-10-29)
# [2020-10-29 12:00] #0516 REPLACE INTO company_info VALUES (043610, 지니뮤직, 2020-10-29)
# [2020-10-29 12:00] #0517 REPLACE INTO company_info VALUES (263860, 지니언스, 2020-10-29)
# [2020-10-29 12:00] #0518 REPLACE INTO company_info VALUES (208350, 지란지교시큐리티, 2020-10-29)
# [2020-10-29 12:00] #0519 REPLACE INTO company_info VALUES (114570, 지스마트글로벌, 2020-10-29)
# [2020-10-29 12:00] #0520 REPLACE INTO company_info VALUES (219750, 지티지웰니스, 2020-10-29)
# [2020-10-29 12:00] #0521 REPLACE INTO company_info VALUES (094850, 참좋은여행, 2020-10-29)
# [2020-10-29 12:00] #0522 REPLACE INTO company_info VALUES (278280, 천보, 2020-10-29)
# [2020-10-29 12:00] #0523 REPLACE INTO company_info VALUES (047820, 초록뱀, 2020-10-29)
# [2020-10-29 12:00] #0524 REPLACE INTO company_info VALUES (078340, 컴투스, 2020-10-29)
# [2020-10-29 12:00] #0525 REPLACE INTO company_info VALUES (330990, 케이비제19호스팩, 2020-10-29)
# [2020-10-29 12:00] #0526 REPLACE INTO company_info VALUES (025880, 케이씨피드, 2020-10-29)
# [2020-10-29 12:00] #0527 REPLACE INTO company_info VALUES (105330, 케이엔더블유, 2020-10-29)
# [2020-10-29 12:00] #0528 REPLACE INTO company_info VALUES (033110, 코너스톤네트웍스, 2020-10-29)
# [2020-10-29 12:00] #0529 REPLACE INTO company_info VALUES (047770, 코데즈컴바인, 2020-10-29)
# [2020-10-29 12:00] #0530 REPLACE INTO company_info VALUES (049430, 코메론, 2020-10-29)
# [2020-10-29 12:00] #0531 REPLACE INTO company_info VALUES (041960, 코미팜, 2020-10-29)
# [2020-10-29 12:00] #0532 REPLACE INTO company_info VALUES (045970, 코아시아, 2020-10-29)
# [2020-10-29 12:00] #0533 REPLACE INTO company_info VALUES (102940, 코오롱생명과학, 2020-10-29)
# [2020-10-29 12:00] #0534 REPLACE INTO company_info VALUES (033290, 코웰패션, 2020-10-29)
# [2020-10-29 12:00] #0535 REPLACE INTO company_info VALUES (056360, 코위버, 2020-10-29)
# [2020-10-29 12:00] #0536 REPLACE INTO company_info VALUES (182360, 큐브엔터, 2020-10-29)
# [2020-10-29 12:00] #0537 REPLACE INTO company_info VALUES (043590, 크로바하이텍, 2020-10-29)
# [2020-10-29 12:00] #0538 REPLACE INTO company_info VALUES (083790, 크리스탈지노믹스, 2020-10-29)
# [2020-10-29 12:00] #0539 REPLACE INTO company_info VALUES (237880, 클리오, 2020-10-29)
# [2020-10-29 12:00] #0540 REPLACE INTO company_info VALUES (311270, 키움제5호스팩, 2020-10-29)
# [2020-10-29 12:00] #0541 REPLACE INTO company_info VALUES (191420, 테고사이언스, 2020-10-29)
# [2020-10-29 12:00] #0542 REPLACE INTO company_info VALUES (073640, 테라사이언스, 2020-10-29)
# [2020-10-29 12:00] #0543 REPLACE INTO company_info VALUES (066700, 테라젠이텍스, 2020-10-29)
# [2020-10-29 12:00] #0544 REPLACE INTO company_info VALUES (131970, 테스나, 2020-10-29)
# [2020-10-29 12:00] #0545 REPLACE INTO company_info VALUES (277880, 티에스아이, 2020-10-29)
# [2020-10-29 12:00] #0546 REPLACE INTO company_info VALUES (043200, 파루, 2020-10-29)
# [2020-10-29 12:00] #0547 REPLACE INTO company_info VALUES (208340, 파멥신, 2020-10-29)
# [2020-10-29 12:00] #0548 REPLACE INTO company_info VALUES (150900, 파수, 2020-10-29)
# [2020-10-29 12:00] #0549 REPLACE INTO company_info VALUES (047310, 파워로직스, 2020-10-29)
# [2020-10-29 12:00] #0550 REPLACE INTO company_info VALUES (038950, 파인디지털, 2020-10-29)
# [2020-10-29 12:00] #0551 REPLACE INTO company_info VALUES (068050, 팬엔터테인먼트, 2020-10-29)
# [2020-10-29 12:00] #0552 REPLACE INTO company_info VALUES (263750, 펄어비스, 2020-10-29)
# [2020-10-29 12:00] #0553 REPLACE INTO company_info VALUES (251970, 펌텍코리아, 2020-10-29)
# [2020-10-29 12:00] #0554 REPLACE INTO company_info VALUES (093380, 풍강, 2020-10-29)
# [2020-10-29 12:00] #0555 REPLACE INTO company_info VALUES (237820, 플레이디, 2020-10-29)
# [2020-10-29 12:00] #0556 REPLACE INTO company_info VALUES (002230, 피에스텍, 2020-10-29)
# [2020-10-29 12:00] #0557 REPLACE INTO company_info VALUES (304840, 피플바이오, 2020-10-29)
# [2020-10-29 12:00] #0558 REPLACE INTO company_info VALUES (347770, 핌스, 2020-10-29)
# [2020-10-29 12:00] #0559 REPLACE INTO company_info VALUES (067310, 하나마이크론, 2020-10-29)
# ...
# [2020-10-29 12:00] #2208 REPLACE INTO company_info VALUES (058470, 리노공업, 2020-10-29)
# [2020-10-29 12:00] #2209 REPLACE INTO company_info VALUES (305090, 마이크로디지탈, 2020-10-29)
# [2020-10-29 12:00] #2210 REPLACE INTO company_info VALUES (038290, 마크로젠, 2020-10-29)
# [2020-10-29 12:00] #2211 REPLACE INTO company_info VALUES (127160, 매직마이크로, 2020-10-29)
# [2020-10-29 12:00] #2212 REPLACE INTO company_info VALUES (093520, 매커스, 2020-10-29)
# [2020-10-29 12:00] #2213 REPLACE INTO company_info VALUES (041920, 메디아나, 2020-10-29)
# [2020-10-29 12:00] #2214 REPLACE INTO company_info VALUES (096640, 멜파스, 2020-10-29)
# [2020-10-29 12:00] #2215 REPLACE INTO company_info VALUES (100030, 모바일리더, 2020-10-29)
# [2020-10-29 12:00] #2216 REPLACE INTO company_info VALUES (218150, 미래생명자원, 2020-10-29)
# [2020-10-29 12:00] #2217 REPLACE INTO company_info VALUES (049950, 미래컴퍼니, 2020-10-29)
# [2020-10-29 12:00] #2218 REPLACE INTO company_info VALUES (064520, 바른전자, 2020-10-29)
# [2020-10-29 12:00] #2219 REPLACE INTO company_info VALUES (267790, 배럴, 2020-10-29)
# [2020-10-29 12:00] #2220 REPLACE INTO company_info VALUES (046310, 백금T&A, 2020-10-29)
# [2020-10-29 12:00] #2221 REPLACE INTO company_info VALUES (066410, 버킷스튜디오, 2020-10-29)
# [2020-10-29 12:00] #2222 REPLACE INTO company_info VALUES (006910, 보성파워텍, 2020-10-29)
# [2020-10-29 12:00] #2223 REPLACE INTO company_info VALUES (251630, 브이원텍, 2020-10-29)
# [2020-10-29 12:00] #2224 REPLACE INTO company_info VALUES (018290, 브이티지엠피, 2020-10-29)
# [2020-10-29 12:00] #2225 REPLACE INTO company_info VALUES (318410, 비비씨, 2020-10-29)
# [2020-10-29 12:00] #2226 REPLACE INTO company_info VALUES (200780, 비씨월드제약, 2020-10-29)
# [2020-10-29 12:00] #2227 REPLACE INTO company_info VALUES (141000, 비아트론, 2020-10-29)
# [2020-10-29 12:00] #2228 REPLACE INTO company_info VALUES (054220, 비츠로시스, 2020-10-29)
# [2020-10-29 12:00] #2229 REPLACE INTO company_info VALUES (072950, 빛샘전자, 2020-10-29)
# [2020-10-29 12:00] #2230 REPLACE INTO company_info VALUES (122350, 삼기, 2020-10-29)
# [2020-10-29 12:00] #2231 REPLACE INTO company_info VALUES (329560, 상상인이안제2호스팩, 2020-10-29)
# [2020-10-29 12:00] #2232 REPLACE INTO company_info VALUES (101000, 상상인인더스트리, 2020-10-29)
# [2020-10-29 12:00] #2233 REPLACE INTO company_info VALUES (294630, 서남, 2020-10-29)
# [2020-10-29 12:00] #2234 REPLACE INTO company_info VALUES (043710, 서울리거, 2020-10-29)
# [2020-10-29 12:00] #2235 REPLACE INTO company_info VALUES (018680, 서울제약, 2020-10-29)
# [2020-10-29 12:00] #2236 REPLACE INTO company_info VALUES (189860, 서전기전, 2020-10-29)
# [2020-10-29 12:00] #2237 REPLACE INTO company_info VALUES (035890, 서희건설, 2020-10-29)
# [2020-10-29 12:00] #2238 REPLACE INTO company_info VALUES (014620, 성광벤드, 2020-10-29)
# [2020-10-29 12:00] #2239 REPLACE INTO company_info VALUES (039310, 세중, 2020-10-29)
# [2020-10-29 12:00] #2240 REPLACE INTO company_info VALUES (051980, 센트럴바이오, 2020-10-29)
# [2020-10-29 12:00] #2241 REPLACE INTO company_info VALUES (091990, 셀트리온헬스케어, 2020-10-29)
# [2020-10-29 12:00] #2242 REPLACE INTO company_info VALUES (036830, 솔브레인홀딩스, 2020-10-29)
# [2020-10-29 12:00] #2243 REPLACE INTO company_info VALUES (304100, 솔트룩스, 2020-10-29)
# [2020-10-29 12:00] #2244 REPLACE INTO company_info VALUES (317770, 슈프리마아이디, 2020-10-29)
# [2020-10-29 12:00] #2245 REPLACE INTO company_info VALUES (002800, 신신제약, 2020-10-29)
# [2020-10-29 12:00] #2246 REPLACE INTO company_info VALUES (344050, 신영스팩6호, 2020-10-29)
# [2020-10-29 12:00] #2247 REPLACE INTO company_info VALUES (012790, 신일제약, 2020-10-29)
# [2020-10-29 12:00] #2248 REPLACE INTO company_info VALUES (160980, 싸이맥스, 2020-10-29)
# [2020-10-29 12:00] #2249 REPLACE INTO company_info VALUES (208640, 썸에이지, 2020-10-29)
# [2020-10-29 12:00] #2250 REPLACE INTO company_info VALUES (050890, 쏠리드, 2020-10-29)
# [2020-10-29 12:00] #2251 REPLACE INTO company_info VALUES (222080, 씨아이에스, 2020-10-29)
# [2020-10-29 12:00] #2252 REPLACE INTO company_info VALUES (297090, 씨에스베어링, 2020-10-29)
# [2020-10-29 12:00] #2253 REPLACE INTO company_info VALUES (025980, 아난티, 2020-10-29)
# [2020-10-29 12:00] #2254 REPLACE INTO company_info VALUES (083930, 아바코, 2020-10-29)
# [2020-10-29 12:00] #2255 REPLACE INTO company_info VALUES (050860, 아세아텍, 2020-10-29)
# [2020-10-29 12:00] #2256 REPLACE INTO company_info VALUES (067390, 아스트, 2020-10-29)
# [2020-10-29 12:00] #2257 REPLACE INTO company_info VALUES (289010, 아이스크림에듀, 2020-10-29)
# [2020-10-29 12:00] #2258 REPLACE INTO company_info VALUES (119830, 아이텍, 2020-10-29)
# [2020-10-29 12:00] #2259 REPLACE INTO company_info VALUES (084850, 아이티엠반도체, 2020-10-29)
# [2020-10-29 12:00] #2260 REPLACE INTO company_info VALUES (297570, 알로이스, 2020-10-29)
# [2020-10-29 12:00] #2261 REPLACE INTO company_info VALUES (030960, 양지사, 2020-10-29)
# [2020-10-29 12:00] #2262 REPLACE INTO company_info VALUES (238120, 얼라인드, 2020-10-29)
# [2020-10-29 12:00] #2263 REPLACE INTO company_info VALUES (042110, 에스씨디, 2020-10-29)
# [2020-10-29 12:00] #2264 REPLACE INTO company_info VALUES (056190, 에스에프에이, 2020-10-29)
# [2020-10-29 12:00] #2265 REPLACE INTO company_info VALUES (069510, 에스텍, 2020-10-29)
# [2020-10-29 12:00] #2266 REPLACE INTO company_info VALUES (050760, 에스폴리텍, 2020-10-29)
# [2020-10-29 12:00] #2267 REPLACE INTO company_info VALUES (317830, 에스피시스템스, 2020-10-29)
# [2020-10-29 12:00] #2268 REPLACE INTO company_info VALUES (200710, 에이디테크놀로지, 2020-10-29)
# [2020-10-29 12:00] #2269 REPLACE INTO company_info VALUES (067630, 에이치엘비생명과학, 2020-10-29)
# [2020-10-29 12:00] #2270 REPLACE INTO company_info VALUES (043220, 에이치엘비파워, 2020-10-29)
# [2020-10-29 12:00] #2271 REPLACE INTO company_info VALUES (230240, 에치에프알, 2020-10-29)
# [2020-10-29 12:00] #2272 REPLACE INTO company_info VALUES (353190, 엔에이치스팩16호, 2020-10-29)
# [2020-10-29 12:00] #2273 REPLACE INTO company_info VALUES (290650, 엘앤씨바이오, 2020-10-29)
# [2020-10-29 12:00] #2274 REPLACE INTO company_info VALUES (066970, 엘앤에프, 2020-10-29)
# [2020-10-29 12:00] #2275 REPLACE INTO company_info VALUES (170920, 엘티씨, 2020-10-29)
# [2020-10-29 12:00] #2276 REPLACE INTO company_info VALUES (033310, 엠투엔, 2020-10-29)
# [2020-10-29 12:00] #2277 REPLACE INTO company_info VALUES (143540, 영우디에스피, 2020-10-29)
# [2020-10-29 12:00] #2278 REPLACE INTO company_info VALUES (036560, 영풍정밀, 2020-10-29)
# [2020-10-29 12:00] #2279 REPLACE INTO company_info VALUES (250930, 예선테크, 2020-10-29)
# [2020-10-29 12:00] #2280 REPLACE INTO company_info VALUES (065500, 오리엔트정공, 2020-10-29)
# [2020-10-29 12:00] #2281 REPLACE INTO company_info VALUES (039200, 오스코텍, 2020-10-29)
# [2020-10-29 12:00] #2282 REPLACE INTO company_info VALUES (173130, 오파스넷, 2020-10-29)
# [2020-10-29 12:00] #2283 REPLACE INTO company_info VALUES (226950, 올릭스, 2020-10-29)
# [2020-10-29 12:00] #2284 REPLACE INTO company_info VALUES (057540, 옴니시스템, 2020-10-29)
# [2020-10-29 12:00] #2285 REPLACE INTO company_info VALUES (079000, 와토스코리아, 2020-10-29)
# [2020-10-29 12:00] #2286 REPLACE INTO company_info VALUES (215360, 우리산업, 2020-10-29)
# [2020-10-29 12:00] #2287 REPLACE INTO company_info VALUES (153490, 우리이앤엘, 2020-10-29)
# [2020-10-29 12:00] #2288 REPLACE INTO company_info VALUES (046940, 우원개발, 2020-10-29)
# [2020-10-29 12:00] #2289 REPLACE INTO company_info VALUES (330350, 위더스제약, 2020-10-29)
# [2020-10-29 12:00] #2290 REPLACE INTO company_info VALUES (038620, 위즈코프, 2020-10-29)
# [2020-10-29 12:00] #2291 REPLACE INTO company_info VALUES (097800, 윈팩, 2020-10-29)
# [2020-10-29 12:00] #2292 REPLACE INTO company_info VALUES (032620, 유비케어, 2020-10-29)
# [2020-10-29 12:00] #2293 REPLACE INTO company_info VALUES (287410, 유안타제3호스팩, 2020-10-29)
# [2020-10-29 12:00] #2294 REPLACE INTO company_info VALUES (056090, 유앤아이, 2020-10-29)
# [2020-10-29 12:00] #2295 REPLACE INTO company_info VALUES (321260, 유진스팩4호, 2020-10-29)
# [2020-10-29 12:00] #2296 REPLACE INTO company_info VALUES (302430, 이노메트리, 2020-10-29)
# [2020-10-29 12:00] #2297 REPLACE INTO company_info VALUES (246960, 이노테라피, 2020-10-29)
# [2020-10-29 12:00] #2298 REPLACE INTO company_info VALUES (215090, 이디티, 2020-10-29)
# [2020-10-29 12:00] #2299 REPLACE INTO company_info VALUES (164060, 이루다, 2020-10-29)
# [2020-10-29 12:00] #2300 REPLACE INTO company_info VALUES (036260, 이매진아시아, 2020-10-29)
# [2020-10-29 12:00] #2301 REPLACE INTO company_info VALUES (323210, 이베스트이안스팩1호, 2020-10-29)
# [2020-10-29 12:00] #2302 REPLACE INTO company_info VALUES (067010, 이씨에스, 2020-10-29)
# [2020-10-29 12:00] #2303 REPLACE INTO company_info VALUES (101360, 이엔드디, 2020-10-29)
# [2020-10-29 12:00] #2304 REPLACE INTO company_info VALUES (039030, 이오테크닉스, 2020-10-29)
# [2020-10-29 12:00] #2305 REPLACE INTO company_info VALUES (119610, 인터로조, 2020-10-29)
# [2020-10-29 12:00] #2306 REPLACE INTO company_info VALUES (150840, 인트로메딕, 2020-10-29)
# [2020-10-29 12:00] #2307 REPLACE INTO company_info VALUES (101930, 인화정공, 2020-10-29)
# [2020-10-29 12:00] #2308 REPLACE INTO company_info VALUES (043910, 자연과환경, 2020-10-29)
# [2020-10-29 12:00] #2309 REPLACE INTO company_info VALUES (022220, 정산애강, 2020-10-29)
# [2020-10-29 12:00] #2310 REPLACE INTO company_info VALUES (123330, 제닉, 2020-10-29)
# [2020-10-29 12:00] #2311 REPLACE INTO company_info VALUES (054950, 제이브이엠, 2020-10-29)
# [2020-10-29 12:00] #2312 REPLACE INTO company_info VALUES (126880, 제이엔케이히터, 2020-10-29)
# [2020-10-29 12:00] #2313 REPLACE INTO company_info VALUES (038010, 제일테크노스, 2020-10-29)
# [2020-10-29 12:00] #2314 REPLACE INTO company_info VALUES (216080, 제테마, 2020-10-29)
# [2020-10-29 12:00] #2315 REPLACE INTO company_info VALUES (053050, 지에스이, 2020-10-29)
# [2020-10-29 12:00] #2316 REPLACE INTO company_info VALUES (270520, 지엔원에너지, 2020-10-29)
# [2020-10-29 12:00] #2317 REPLACE INTO company_info VALUES (111820, 지와이커머스, 2020-10-29)
# [2020-10-29 12:00] #2318 REPLACE INTO company_info VALUES (007370, 진양제약, 2020-10-29)
# [2020-10-29 12:00] #2319 REPLACE INTO company_info VALUES (085660, 차바이오텍, 2020-10-29)
# [2020-10-29 12:00] #2320 REPLACE INTO company_info VALUES (311690, 천랩, 2020-10-29)
# [2020-10-29 12:00] #2321 REPLACE INTO company_info VALUES (214370, 케어젠, 2020-10-29)
# [2020-10-29 12:00] #2322 REPLACE INTO company_info VALUES (043290, 케이맥, 2020-10-29)
# [2020-10-29 12:00] #2323 REPLACE INTO company_info VALUES (039420, 케이엘넷, 2020-10-29)
# [2020-10-29 12:00] #2324 REPLACE INTO company_info VALUES (347140, 케이프이에스제4호, 2020-10-29)
# [2020-10-29 12:00] #2325 REPLACE INTO company_info VALUES (104540, 코렌텍, 2020-10-29)
# [2020-10-29 12:00] #2326 REPLACE INTO company_info VALUES (027050, 코리아나, 2020-10-29)
# [2020-10-29 12:00] #2327 REPLACE INTO company_info VALUES (222040, 코스맥스엔비티, 2020-10-29)
# [2020-10-29 12:00] #2328 REPLACE INTO company_info VALUES (950160, 코오롱티슈진, 2020-10-29)
# [2020-10-29 12:00] #2329 REPLACE INTO company_info VALUES (015710, 코콤, 2020-10-29)
# [2020-10-29 12:00] #2330 REPLACE INTO company_info VALUES (066310, 큐에스아이, 2020-10-29)
# [2020-10-29 12:00] #2331 REPLACE INTO company_info VALUES (114120, 크루셜텍, 2020-10-29)
# [2020-10-29 12:00] #2332 REPLACE INTO company_info VALUES (110790, 크리스에프앤씨, 2020-10-29)
# [2020-10-29 12:00] #2333 REPLACE INTO company_info VALUES (095610, 테스, 2020-10-29)
# [2020-10-29 12:00] #2334 REPLACE INTO company_info VALUES (054450, 텔레칩스, 2020-10-29)
# [2020-10-29 12:00] #2335 REPLACE INTO company_info VALUES (091440, 텔레필드, 2020-10-29)
# [2020-10-29 12:00] #2336 REPLACE INTO company_info VALUES (108230, 톱텍, 2020-10-29)
# [2020-10-29 12:00] #2337 REPLACE INTO company_info VALUES (033830, 티비씨, 2020-10-29)
# [2020-10-29 12:00] #2338 REPLACE INTO company_info VALUES (081150, 티플랙스, 2020-10-29)
# [2020-10-29 12:00] #2339 REPLACE INTO company_info VALUES (046210, 파나진, 2020-10-29)
# [2020-10-29 12:00] #2340 REPLACE INTO company_info VALUES (170790, 파이오링크, 2020-10-29)
# [2020-10-29 12:00] #2341 REPLACE INTO company_info VALUES (016670, 포비스티앤씨, 2020-10-29)
# [2020-10-29 12:00] #2342 REPLACE INTO company_info VALUES (189690, 포시에스, 2020-10-29)
# [2020-10-29 12:00] #2343 REPLACE INTO company_info VALUES (094940, 푸른기술, 2020-10-29)
# [2020-10-29 12:00] #2344 REPLACE INTO company_info VALUES (195440, 퓨전, 2020-10-29)
# [2020-10-29 12:00] #2345 REPLACE INTO company_info VALUES (035200, 프럼파스트, 2020-10-29)
# [2020-10-29 12:00] #2346 REPLACE INTO company_info VALUES (300080, 플리토, 2020-10-29)
# [2020-10-29 12:00] #2347 REPLACE INTO company_info VALUES (347740, 피엔케이피부임상연구센타, 2020-10-29)
# [2020-10-29 12:00] #2348 REPLACE INTO company_info VALUES (006140, 피제이전자, 2020-10-29)
# [2020-10-29 12:00] #2349 REPLACE INTO company_info VALUES (136480, 하림, 2020-10-29)
# [2020-10-29 12:00] #2350 REPLACE INTO company_info VALUES (013030, 하이록코리아, 2020-10-29)
# [2020-10-29 12:00] #2351 REPLACE INTO company_info VALUES (126700, 하이비젼시스템, 2020-10-29)
# [2020-10-29 12:00] #2352 REPLACE INTO company_info VALUES (066130, 하츠, 2020-10-29)
# [2020-10-29 12:00] #2353 REPLACE INTO company_info VALUES (034950, 한국기업평가, 2020-10-29)
# [2020-10-29 12:00] #2354 REPLACE INTO company_info VALUES (039740, 한국정보공학, 2020-10-29)
# [2020-10-29 12:00] #2355 REPLACE INTO company_info VALUES (052600, 한네트, 2020-10-29)
# [2020-10-29 12:00] #2356 REPLACE INTO company_info VALUES (092460, 한라IMS, 2020-10-29)
# [2020-10-29 12:00] #2357 REPLACE INTO company_info VALUES (045100, 한양이엔지, 2020-10-29)
# [2020-10-29 12:00] #2358 REPLACE INTO company_info VALUES (066110, 한프, 2020-10-29)
# [2020-10-29 12:00] #2359 REPLACE INTO company_info VALUES (034810, 해성산업, 2020-10-29)
# [2020-10-29 12:00] #2360 REPLACE INTO company_info VALUES (076610, 해성옵틱스, 2020-10-29)
# [2020-10-29 12:00] #2361 REPLACE INTO company_info VALUES (008800, 행남사, 2020-10-29)
# [2020-10-29 12:00] #2362 REPLACE INTO company_info VALUES (060560, 홈센타홀딩스, 2020-10-29)
# [2020-10-29 12:00] #2363 REPLACE INTO company_info VALUES (238490, 힘스, 2020-10-29)
# [2020-10-29 12:00] #2364 REPLACE INTO company_info VALUES (224880, SGA클라우드서비스, 2020-10-29)
# [2020-10-29 12:00] #2365 REPLACE INTO company_info VALUES (284610, TS트릴리온, 2020-10-29)
# [2020-10-29 12:00] #2366 REPLACE INTO company_info VALUES (076340, 관악산업, 2020-10-29)
# [2020-10-29 12:00] #2367 REPLACE INTO company_info VALUES (288490, 나라소프트, 2020-10-29)
# [2020-10-29 12:00] #2368 REPLACE INTO company_info VALUES (348840, 데이드림엔터, 2020-10-29)
# [2020-10-29 12:00] #2369 REPLACE INTO company_info VALUES (162120, 루켄테크놀러지스, 2020-10-29)
# [2020-10-29 12:00] #2370 REPLACE INTO company_info VALUES (236340, 메디젠휴먼케어, 2020-10-29)
# [2020-10-29 12:00] #2371 REPLACE INTO company_info VALUES (258250, 셀젠텍, 2020-10-29)
# [2020-10-29 12:00] #2372 REPLACE INTO company_info VALUES (223220, 아이피몬스터, 2020-10-29)
# [2020-10-29 12:00] #2373 REPLACE INTO company_info VALUES (224020, 에스케이씨에스, 2020-10-29)
# [2020-10-29 12:00] #2374 REPLACE INTO company_info VALUES (207490, 에이펙스인텍, 2020-10-29)
# [2020-10-29 12:00] #2375 REPLACE INTO company_info VALUES (238170, 엔에스엠, 2020-10-29)
# [2020-10-29 12:00] #2376 REPLACE INTO company_info VALUES (278380, 원바이오젠, 2020-10-29)
# [2020-10-29 12:00] #2377 REPLACE INTO company_info VALUES (216280, 원텍, 2020-10-29)
# [2020-10-29 12:00] #2378 REPLACE INTO company_info VALUES (344860, 이노진, 2020-10-29)
# [2020-10-29 12:00] #2379 REPLACE INTO company_info VALUES (299480, 지앤이헬스케어, 2020-10-29)
# [2020-10-29 12:00] #2380 REPLACE INTO company_info VALUES (189350, 코셋, 2020-10-29)
# [2020-10-29 12:00] #2381 REPLACE INTO company_info VALUES (199800, 툴젠, 2020-10-29)
# [2020-10-29 12:00] #2382 REPLACE INTO company_info VALUES (222670, 플럼라인생명과학, 2020-10-29)
# [2020-10-29 12:00] #2383 REPLACE INTO company_info VALUES (239890, 피엔에이치테크, 2020-10-29)
# [2020-10-29 12:00] #2384 REPLACE INTO company_info VALUES (331660, 한국미라클피플사, 2020-10-29)
# [2020-10-29 12:00] #2385 REPLACE INTO company_info VALUES (212310, 휴벡셀, 2020-10-29)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-c0d606f70444> in <module>
#     168 if __name__ == '__main__':
#     169     dbu = DBUpdater()
# --> 170     dbu.execute_daily()
#
# <ipython-input-1-c0d606f70444> in execute_daily(self)
#     139             with open('config.json', 'r') as in_file:
#     140                 config = json.load(in_file)
# --> 141                 pages_to_fetch = config['pages_to_fetch']
#     142         except FileNotFoundError:
#     143             with open('config.json', 'w') as out_file:
#
# KeyError: 'pages_to_fetch'
