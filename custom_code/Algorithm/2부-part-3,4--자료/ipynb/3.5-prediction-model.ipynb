# %% [markdown]
# # 예측 모형 실습: 쿠폰 지급을 위한 예측 모형
#
# 배송료 무료 쿠폰을 줬을 때, 구매 가능성이 가장 높을 유저를 예측

# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from xgboost import XGBClassifier

# %%
df = pd.read_csv('/content/gooppang.csv')
df.dtypes
# Out:
# age              float64
# basket           float64
# checkout            bool
# region            object
# coupon              bool
# gender            object
# monthly_spend    float64
# shipping_fee     float64
# subscriber          bool
# tenure           float64
# dtype: object

# %%
train_df, test_df = train_test_split(df, train_size=0.8, random_state=0)

# %%
# Column selection
ct = ColumnTransformer([
  ('bin', 'passthrough', ['coupon', 'subscriber']),
  ('cat', OneHotEncoder(drop='first'), ['region', 'gender']),
  ('num', StandardScaler(), ['age', 'monthly_spend', 'tenure']),
])

# %% [markdown]
# # Example with logistic regression

# %%
# Vanilla logistic regression
lr_pipe = Pipeline([
  ('trans', ct),
  ('clf', LogisticRegression()),
])
lr_pipe.fit(train_df, y=train_df.checkout)
# Out:
# Pipeline(steps=[('trans',
#                  ColumnTransformer(transformers=[('bin', 'passthrough',
#                                                   ['coupon', 'subscriber']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['region', 'gender']),
#                                                  ('num', StandardScaler(),
#                                                   ['age', 'monthly_spend',
#                                                    'tenure'])])),
#                 ('clf', LogisticRegression())])

# %%
train_roc_auc = roc_auc_score(y_true=train_df.checkout, y_score=lr_pipe.predict_proba(train_df)[:, 1])
test_roc_auc = roc_auc_score(y_true=test_df.checkout, y_score=lr_pipe.predict_proba(test_df)[:, 1])
print(f'ROC AUC: {train_roc_auc:.2f} (train), {test_roc_auc:.2f} (test)')
# Out:
# ROC AUC: 0.68 (train), 0.67 (test)

# %%
# Regularized logistic regrssion w/ CV
lr_grid_params = {
  'clf__C': np.logspace(-2, 2, 10),
}
lr_gs = GridSearchCV(lr_pipe, lr_grid_params, scoring='roc_auc', n_jobs=-1)
lr_gs = lr_gs.fit(train_df, y=train_df.checkout)
lr_gs.cv_results_
# Out:
# {'mean_fit_time': array([0.24679217, 0.28523946, 0.28598151, 0.31955605, 0.32527761,
#         0.33229818, 0.32082562, 0.3353507 , 0.33506613, 0.31481252]),
#  'mean_score_time': array([0.03005567, 0.02704015, 0.02656927, 0.02650957, 0.02682438,
#         0.02607336, 0.02746377, 0.03036914, 0.02669311, 0.02457561]),
#  'mean_test_score': array([0.67169036, 0.67421546, 0.67539772, 0.67594987, 0.67597137,
#         0.67594722, 0.67592943, 0.67593617, 0.67593863, 0.67593939]),
#  'param_clf__C': masked_array(data=[0.01, 0.027825594022071243, 0.0774263682681127,
#                     0.21544346900318834, 0.5994842503189409,
#                     1.6681005372000592, 4.6415888336127775,
#                     12.915496650148826, 35.93813663804626, 100.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'clf__C': 0.01},
#   {'clf__C': 0.027825594022071243},
#   {'clf__C': 0.0774263682681127},
#   {'clf__C': 0.21544346900318834},
#   {'clf__C': 0.5994842503189409},
#   {'clf__C': 1.6681005372000592},
#   {'clf__C': 4.6415888336127775},
#   {'clf__C': 12.915496650148826},
#   {'clf__C': 35.93813663804626},
#   {'clf__C': 100.0}],
#  'rank_test_score': array([10,  9,  8,  2,  1,  3,  7,  6,  5,  4], dtype=int32),
#  'split0_test_score': array([0.66072358, 0.66213246, 0.66308158, 0.66366252, 0.66401058,
#         0.66416483, 0.66418694, 0.66419791, 0.66419974, 0.66420257]),
#  'split1_test_score': array([0.68225882, 0.68550729, 0.68721187, 0.68830028, 0.6887619 ,
#         0.68890765, 0.68895877, 0.68898915, 0.68899761, 0.68899795]),
#  'split2_test_score': array([0.66633169, 0.66935807, 0.67069879, 0.67096255, 0.670974  ,
#         0.67101699, 0.67101318, 0.67100305, 0.67100421, 0.67100272]),
#  'split3_test_score': array([0.6650699 , 0.66691889, 0.66784081, 0.66816101, 0.66772229,
#         0.66756527, 0.66748542, 0.66748941, 0.66748974, 0.66748924]),
#  'split4_test_score': array([0.68406781, 0.68716058, 0.68815553, 0.68866297, 0.68838809,
#         0.68808134, 0.68800282, 0.68800133, 0.68800183, 0.68800448]),
#  'std_fit_time': array([0.01091535, 0.01772565, 0.02014078, 0.00386875, 0.00683123,
#         0.0258703 , 0.01826187, 0.0199013 , 0.01416218, 0.04063582]),
#  'std_score_time': array([0.00663808, 0.0007858 , 0.00033032, 0.00040057, 0.00088125,
#         0.0003124 , 0.00071117, 0.00523743, 0.00072128, 0.00419767]),
#  'std_test_score': array([0.00956775, 0.01017757, 0.01032676, 0.01049452, 0.01052477,
#         0.01047472, 0.01047747, 0.01048254, 0.01048419, 0.01048448])}

# %%
lr_test_preds = lr_gs.best_estimator_.predict_proba(test_df)[:, 1]
roc_auc_score(y_true=test_df.checkout, y_score=lr_test_preds)
# Out:
# 0.6695381247188712

# %%
test_with_coupon_df = test_df.assign(coupon=1)
p_checkout_with_coupon = lr_gs.best_estimator_.predict_proba(test_with_coupon_df)[:, 1]
(
    test_df
    .assign(p_checkout=p_checkout_with_coupon)
    .sort_values('p_checkout', ascending=False)
)
# Out:
#         age  basket  checkout  ... subscriber  tenure p_checkout
# 28396  31.0    87.8      True  ...       True    49.0   0.570723
# 2482   68.0    99.4     False  ...       True    41.0   0.554410
# 3913   75.0    81.2     False  ...       True    39.0   0.534344
# 35826  31.0    39.5     False  ...       True    48.0   0.494141
# 16346  38.0    76.7     False  ...       True    23.0   0.478561
# ...     ...     ...       ...  ...        ...     ...        ...
# 14870  38.0   184.3     False  ...      False     3.0   0.016662
# 14708  35.0   168.0     False  ...      False     2.0   0.016580
# 32924  34.0   165.4     False  ...      False     3.0   0.016437
# 58441  34.0   182.7     False  ...      False     2.0   0.016324
# 8457   27.0   161.2     False  ...      False     3.0   0.016236
#
# [12000 rows x 11 columns]

# %% [markdown]
# # Example with XGBoost Classifier

# %%
# Vanilla XGBoost
xgb_pipe = Pipeline([
  ('trans', ct),
  ('clf', XGBClassifier()),
])
xgb_pipe.fit(train_df, y=train_df.checkout)
train_roc_auc = roc_auc_score(y_true=train_df.checkout, y_score=xgb_pipe.predict_proba(train_df)[:, 1])
test_roc_auc = roc_auc_score(y_true=test_df.checkout, y_score=xgb_pipe.predict_proba(test_df)[:, 1])
print(f'ROC AUC: {train_roc_auc:.2f} (train), {test_roc_auc:.2f} (test)')
# Out:
# ROC AUC: 0.69 (train), 0.67 (test)

# %%
xgb_grid_params = {
  'clf__max_depth': range(1, 7),
}
xgb_gs = GridSearchCV(xgb_pipe, xgb_grid_params, scoring='roc_auc', n_jobs=-1)
xgb_gs = xgb_gs.fit(train_df, y=train_df.checkout)
xgb_gs.cv_results_
# Out:
# {'mean_fit_time': array([1.74624119, 2.32282157, 3.01122279, 3.74382057, 4.55158944,
#         5.16608725]),
#  'mean_score_time': array([0.05154123, 0.05717463, 0.06533656, 0.07574782, 0.08850231,
#         0.0960104 ]),
#  'mean_test_score': array([0.67394145, 0.67480953, 0.67164048, 0.67052668, 0.66691607,
#         0.66219534]),
#  'param_clf__max_depth': masked_array(data=[1, 2, 3, 4, 5, 6],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'clf__max_depth': 1},
#   {'clf__max_depth': 2},
#   {'clf__max_depth': 3},
#   {'clf__max_depth': 4},
#   {'clf__max_depth': 5},
#   {'clf__max_depth': 6}],
#  'rank_test_score': array([2, 1, 3, 4, 5, 6], dtype=int32),
#  'split0_test_score': array([0.66386306, 0.66264234, 0.65884879, 0.65543097, 0.65393142,
#         0.65002542]),
#  'split1_test_score': array([0.68849764, 0.68835705, 0.68682087, 0.68657056, 0.68307766,
#         0.67712775]),
#  'split2_test_score': array([0.66749787, 0.6671824 , 0.66302728, 0.66191837, 0.65948161,
#         0.65949771]),
#  'split3_test_score': array([0.66402349, 0.66684486, 0.66321768, 0.66485752, 0.66096209,
#         0.65526723]),
#  'split4_test_score': array([0.68582517, 0.68902102, 0.68628779, 0.683856  , 0.67712759,
#         0.66905862]),
#  'std_fit_time': array([0.04692877, 0.02166046, 0.02559692, 0.02505427, 0.04450989,
#         0.33504169]),
#  'std_score_time': array([0.00886164, 0.00434323, 0.00185777, 0.00176132, 0.00146169,
#         0.01081772]),
#  'std_test_score': array([0.01090473, 0.01144684, 0.012278  , 0.01240322, 0.0111785 ,
#         0.00973103])}

# %%
xgb_test_preds = xgb_gs.best_estimator_.predict_proba(test_df)[:, 1]
roc_auc_score(y_true=test_df.checkout, y_score=xgb_test_preds)
# Out:
# 0.6668948681978104
